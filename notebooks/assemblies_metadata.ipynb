# %%
# !conda info --envs

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import re
from collections import defaultdict
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# # Create files with scientific and common names for all the amniota
# Use those list as regex patterns for searching inside the biosample and bioproject information

# %% [markdown]
# ###  Download the `taxdump.tar.gz` from the NCBI ftp and place this in your bash profile
# ```sh
# export TAXONKIT_DB=/home/mibu/Bif_Data/taxdump
# ```
# Then, we can create a list of taxids of all the specia under 'Amniota' with their ranks and scientific names:
#
# ```sh
#  taxonkit list --ids 32524 | taxonkit filter -E species | taxonkit lineage -L -n > amniota_sp.list
# ```
# `-L`: Only include the names, not the lineage. `list` doesn't accept the input from `filter`
#
# There is no option to retrieve "common names", but we can get that information from  `names.dmp`

# %% [markdown]
# ## One pipe:
# ```bash
# names="taxdump/names.dmp"
#
# taxonkit list --ids 32524 | taxonkit filter -E species | taxonkit lineage -L -n | cut -f1 | \
# rg -f - $names | rg 'common name' | cut -d '|' -f2 | tr -d '\t' > ~/common_names_ncbi.list
# ```

# %%
sample = Path("/run/media/mibu/LR-orico_mini/Recovery_ADATA/Umayor/Work/Blautia/Notebooks/biosample_descr_akk.tsv")
common_pats = Path("/home/mibu/common_names_ncbi.list")
common_pats.exists(), sample.exists()
# Out:
# (True, True)

# %%
sample_desc_all = Path("/run/media/mibu/LR-orico_mini/Recovery_ADATA/Umayor/Work/Blautia/Notebooks/biosample_descr_non_akk.tsv")
assert sample_desc_all.exists() == True

# %% [markdown]
# **Get only the species names, withot the taxids**

# %%
! cut -f2 ~/amniota_sp.list > ~/amniota_only_sp.list

# %%
sp_pats = Path("/home/mibu/amniota_only_sp.list")
assert sp_pats.exists() == True

# %%
merged_df = pd.read_csv('/run/media/mibu/LR-orico_mini/Recovery_ADATA/Umayor/Work/Akker/Verrucomicrobia/QC/verrocu_seqs_summary.tsv', sep='\t')
merged_df.info()
merged_df['host'].value_counts(), merged_df['host'].isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 585 entries, 0 to 584
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Genome                       585 non-null    object
#  1   Completeness                 585 non-null    float64
#  2   Contamination                585 non-null    float64
#  3   classification               585 non-null    object
#  4   classification_method        585 non-null    object
#  5   sum_len                      585 non-null    int64
#  6   N50                          585 non-null    int64
#  7   16S ribosomal RNA > 1400 nt  304 non-null    float64
#  8   Total_tRNAs                  585 non-null    int64
#  9   host                         8 non-null      object
#  10  NCBI_organism_name           212 non-null    object
#  11  NCBI_infraspecific_name      195 non-null    object
#  12  relation_to_type_material    40 non-null     object
# dtypes: float64(3), int64(3), object(7)
# memory usage: 59.5+ KB
# (Mouse                  3
#  Choloepus hoffmanni    1
#  Diceros bicornis       1
#  Bufo bufo              1
#  Horse                  1
#  Gallus gallus          1
#  Name: host, dtype: int64,
#  577)

# %%
qc_path = Path('/run/media/mibu/LR-orico_mini/Recovery_ADATA/Umayor/Work/Akker/Verrucomicrobia/QC/')
# merged_df = pd.read_csv(qc_path.joinpath('verrocu_seqs_summary_2.tsv'), sep='\t')
# merged_df.info()
# merged_df['host'].value_counts(), merged_df['host'].isna().sum()

# %%
non_akk_ncbi = merged_df[~merged_df['classification'].str.contains('g__Akkermansia')]#.loc[:, 'Genome'].str.extract('(GC[AF]_[0-9]{9}\.[1-9]{1,2})').dropna().values
non_akk_ncbi.info()
print(non_akk_ncbi['host'].value_counts())
non_akk_ncbi.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 384 entries, 2 to 562
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Genome                       384 non-null    object
#  1   Completeness                 384 non-null    float64
#  2   Contamination                384 non-null    float64
#  3   classification               384 non-null    object
#  4   classification_method        384 non-null    object
#  5   sum_len                      384 non-null    int64
#  6   N50                          384 non-null    int64
#  7   16S ribosomal RNA > 1400 nt  153 non-null    float64
#  8   Total_tRNAs                  384 non-null    int64
#  9   host                         0 non-null      object
#  10  NCBI_organism_name           65 non-null     object
#  11  NCBI_infraspecific_name      55 non-null     object
#  12  relation_to_type_material    36 non-null     object
#  13  type_of_sample               0 non-null      object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 45.0+ KB
# Series([], Name: host, dtype: int64)
#                                Genome  Completeness  Contamination  \
# 2  GCA_000155695.1_ASM15569v1_genomic         100.0           1.35
# 3  GCA_000242935.3_ASM24293v3_genomic         100.0           0.23
#
#                                       classification  \
# 2  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 3  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
#
#                                classification_method  sum_len      N50  \
# 2  taxonomic classification defined by topology a...  5775745  5514226
# 3  taxonomic classification defined by topology a...  7417673  7317842
#
#    16S ribosomal RNA > 1400 nt  Total_tRNAs host NCBI_organism_name  \
# 2                          1.0           45  NaN                NaN
# 3                          1.0           52  NaN                NaN
#
#   NCBI_infraspecific_name relation_to_type_material type_of_sample
# 2                     NaN                       NaN            NaN
# 3                     NaN                       NaN            NaN

# %% [markdown]
# ### Read the refseq and genbank summary tables

# %%
ncbi_df = pd.read_feather('/run/media/mibu/LR-orico_mini/Recovery_ADATA/Umayor/Data/ncbi_summ_tables.feather')
ncbi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1158218 entries, 0 to 1158217
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Genome                     1158163 non-null  object
#  1   assembly_accession         1158218 non-null  object
#  2   bioproject                 1158214 non-null  object
#  3   biosample                  1158213 non-null  object
#  4   wgs_master                 1104090 non-null  object
#  5   refseq_category            1158218 non-null  object
#  6   taxid                      1158218 non-null  int64
#  7   species_taxid              1158218 non-null  int64
#  8   NCBI_organism_name         1158218 non-null  object
#  9   NCBI_infraspecific_name    998033 non-null   object
#  10  isolate                    182630 non-null   object
#  11  version_status             1158218 non-null  object
#  12  assembly_level             1158218 non-null  object
#  13  release_type               1158218 non-null  object
#  14  genome_rep                 1158218 non-null  object
#  15  seq_rel_date               1158218 non-null  object
#  16  asm_name                   1158217 non-null  object
#  17  submitter                  1158210 non-null  object
#  18  gbrs_paired_asm            1158218 non-null  object
#  19  paired_asm_comp            1158218 non-null  object
#  20  ftp_path                   1158218 non-null  object
#  21  excluded_from_refseq       726985 non-null   object
#  22  relation_to_type_material  32556 non-null    object
# dtypes: int64(2), object(21)
# memory usage: 203.2+ MB

# %% [markdown]
# ### Create indexes for the akkermasia and non-akkermasia assemblies

# %%
akk_ncbi = merged_df[merged_df['classification'].str.contains('g__Akkermansia')].loc[:, 'Genome'].str.extract('(GC[AF]_[0-9]{9}\.[1-9]{1,2})').dropna().values
akk_ncbi[:5], akk_ncbi.shape
# Out:
# (array([['GCA_000436395.1'],
#         ['GCA_000437075.1'],
#         ['GCA_001917295.1'],
#         ['GCA_002362435.1'],
#         ['GCA_002492685.1']], dtype=object),
#  (180, 1))

# %%
non_akk_ncbi = merged_df[~merged_df['classification'].str.contains('g__Akkermansia')].loc[:, 'Genome'].str.extract('(GC[AF]_[0-9]{9}\.[1-9]{1,2})').dropna().values
non_akk_ncbi[:5], non_akk_ncbi.shape
# Out:
# (array([['GCA_000155695.1'],
#         ['GCA_000242935.3'],
#         ['GCA_000243495.3'],
#         ['GCA_000526255.1'],
#         ['GCA_000739615.1']], dtype=object),
#  (384, 1))

# %% [markdown]
# ### For BioSample

# %%
# des_files = ['biosample_descr_akk.tsv', 'biosample_descr_non_akk.tsv']
# idxs = [akk_ncbi, non_akk_ncbi]
# for des_file,accs in zip(des_files, idxs):
#     print(des_file)
#     ! rm $des_file
#     bs_descr = defaultdict()
#     fh = open(des_file, 'a')
#     # fh.write('Biosample\tProject_Description\tProject_Name\tProject_Title\n')
#     for idx,bs in ncbi_df.set_index('assembly_accession').loc[accs.flatten(), :]['biosample'].iteritems():
#         print(idx, bs)
#         desc = ! esearch -db biosample -query $bs | efetch -format docsum | xtract -pattern DocumentSummary -element Title Attribute 
#         desc_ls = desc.get_spstr().split('\t')
#         desc_ls.insert(0, bs)
#         desc_ls.insert(0, idx)
#         bs_descr[idx] = desc_ls
#         print('\t'.join(desc_ls), file=fh)
#     fh.close()
# Out:
# biosample_descr_akk.tsv
# GCA_000436395.1 SAMEA3138704
# GCA_000437075.1 SAMEA3138738
# GCA_001917295.1 SAMN05717313
# GCA_002362435.1 SAMN06457624
# GCA_002492685.1 SAMN06455865
# GCA_002493465.1 SAMN06455314
# GCA_003514565.1 SAMN08019340
# GCA_008672035.1 SAMN10316569
# GCA_008672205.1 SAMN10316561
# GCA_009773845.1 SAMN12406434
# GCA_014871965.1 SAMN12905381
# GCA_014871995.1 SAMN12905379
# GCA_014872005.1 SAMN12905380
# GCA_014872035.1 SAMN12905378
# GCA_014872065.1 SAMN12905377
# GCA_014872075.1 SAMN12905375
# GCA_014872105.1 SAMN12905376
# GCA_014872125.1 SAMN12905373
# GCA_014872165.1 SAMN12905372
# GCA_900539575.1 SAMEA4890833
# GCA_900539895.1 SAMEA4890871
# GCA_900545155.1 SAMEA4891402
# GCA_900752515.1 SAMEA5279134
# GCA_900759685.1 SAMEA5279138
# GCA_900765745.1 SAMEA5279136
# GCA_905193715.1 SAMEA7847250
# GCA_905197035.1 SAMEA7847110
# GCA_905200125.1 SAMEA7848347
# GCA_905200945.1 SAMEA7847584
# GCA_905205055.1 SAMEA7848078
# GCA_905205915.1 SAMEA7846587
# GCA_905210405.1 SAMEA7847399
# GCA_905210615.1 SAMEA7847488
# GCF_000020225.1 SAMN00138213
# GCF_000723745.2 SAMEA3139045
# GCF_001578645.1 SAMN03956217
# GCF_001580195.1 SAMN03956447
# GCF_001647615.1 SAMN04606485
# GCF_001688765.2 SAMN04621615
# GCF_002161325.1 SAMN06473757
# GCF_002201495.1 SAMN03854119
# GCF_002884915.1 SAMN08162557
# GCF_002884975.1 SAMN08162556
# GCF_002884995.1 SAMN08162554
# GCF_002885015.1 SAMN08162551
# GCF_002885025.1 SAMN08162552
# GCF_002885055.1 SAMN08162550
# GCF_002885075.1 SAMN08162548
# GCF_002885095.1 SAMN08162547
# GCF_002885155.1 SAMN08162544
# GCF_002885165.1 SAMN08162543
# GCF_002885195.1 SAMN08162540
# GCF_002885215.1 SAMN08162539
# GCF_002885235.1 SAMN08162538
# GCF_002885255.1 SAMN08162534
# GCF_002885265.1 SAMN08162533
# GCF_002885295.1 SAMN08162531
# GCF_002885315.1 SAMN08162529
# GCF_002885335.1 SAMN08162528
# GCF_002885355.1 SAMN08162527
# GCF_002885375.1 SAMN08162526
# GCF_002885395.1 SAMN08162525
# GCF_002885415.1 SAMN08162524
# GCF_002885425.1 SAMN08162523
# GCF_002885455.1 SAMN08162522
# GCF_002885465.1 SAMN08162520
# GCF_002885515.1 SAMN08162555
# GCF_002885535.1 SAMN08162553
# GCF_002885575.1 SAMN08162542
# GCF_002885595.1 SAMN08162541
# GCF_002885615.1 SAMN08162537
# GCF_002885625.1 SAMN08162536
# GCF_002885655.1 SAMN08162535
# GCF_002885675.1 SAMN08162532
# GCF_002885695.1 SAMN08162530
# GCF_002885715.1 SAMN08162521
# GCF_003716915.1 SAMN07978491
# GCF_003716935.1 SAMN07980909
# GCF_003716955.1 SAMN07980958
# GCF_003716975.1 SAMN07980963
# GCF_004015005.1 SAMN08329147
# GCF_004015025.1 SAMN08329199
# GCF_004015045.1 SAMN08334970
# GCF_004015065.1 SAMN08334973
# GCF_004015085.1 SAMN08334978
# GCF_004015105.1 SAMN08334979
# GCF_004015125.1 SAMN08334983
# GCF_004015205.1 SAMN08334976
# GCF_004015225.1 SAMN08334977
# GCF_004015245.1 SAMN08328879
# GCF_004015265.1 SAMN08329008
# GCF_004015285.1 SAMN08334972
# GCF_004015305.1 SAMN08334975
# GCF_004015325.1 SAMN08334981
# GCF_004015345.1 SAMN08334982
# GCF_004104435.1 SAMN10186677
# GCF_004168105.1 SAMN10239579
# GCF_004319565.1 SAMN10963682
# GCF_008000975.1 SAMN12556229
# GCF_008422275.1 SAMN11943062
# GCF_008422615.1 SAMN11943045
# GCF_008422635.1 SAMN11943044
# GCF_008422665.1 SAMN11943043
# GCF_008422685.1 SAMN11943039
# GCF_008422695.1 SAMN11943041
# GCF_008422705.1 SAMN11943040
# GCF_008422715.1 SAMN11943042
# GCF_008422765.1 SAMN11943036
# GCF_008422775.1 SAMN11943037
# GCF_008422795.1 SAMN11943035
# GCF_008422805.1 SAMN11943034
# GCF_008422815.1 SAMN11943038
# GCF_008422865.1 SAMN11943032
# GCF_008422875.1 SAMN11943030
# GCF_008422885.1 SAMN11943033
# GCF_008422895.1 SAMN11943031
# GCF_008422925.1 SAMN11943029
# GCF_008422965.1 SAMN11943027
# GCF_008422985.1 SAMN11943026
# GCF_008422995.1 SAMN11943028
# GCF_008423015.1 SAMN11943024
# GCF_008423035.1 SAMN11943025
# GCF_008423065.1 SAMN11943023
# GCF_008423085.1 SAMN11943021
# GCF_008423095.1 SAMN11943022
# GCF_008423115.1 SAMN11943020
# GCF_008423135.1 SAMN11943019
# GCF_008423175.1 SAMN11943018
# GCF_008423185.1 SAMN11943016
# GCF_008423215.1 SAMN11943015
# GCF_008423245.1 SAMN11943014
# GCF_008423265.1 SAMN11943013
# GCF_008423275.1 SAMN11943011
# GCF_008423295.1 SAMN11943009
# GCF_008423325.1 SAMN11943008
# GCF_008423335.1 SAMN11943007
# GCF_008423365.1 SAMN11943006
# GCF_008423375.1 SAMN11943004
# GCF_008423385.1 SAMN11943003
# GCF_008423405.1 SAMN11943005
# GCF_008423445.1 SAMN11943002
# GCF_008423455.1 SAMN11943001
# GCF_009663785.1 SAMN10240011
# GCF_009731575.1 SAMD00192834
# GCF_010223015.1 SAMN08563913
# GCF_010223075.1 SAMN08563914
# GCF_010223095.1 SAMN08565495
# GCF_010223115.1 SAMN08565496
# GCF_010223135.1 SAMN08565497
# GCF_010223155.1 SAMN08565498
# GCF_010223175.1 SAMN08565499
# GCF_010223195.1 SAMN08565501
# GCF_010223255.1 SAMN08565500
# GCF_010223405.1 SAMN08565502
# GCF_010223575.1 SAMN08565503
# GCF_010229055.1 SAMN09287185
# GCF_010229495.1 SAMN09287631
# GCF_010229695.1 SAMN09287781
# GCF_010229955.1 SAMN09287782
# GCF_010230155.1 SAMN09287783
# GCF_010230375.1 SAMN09287787
# GCF_010230515.1 SAMN09288166
# GCF_010230725.1 SAMN09288168
# GCF_010230935.1 SAMN09288183
# GCF_010231195.1 SAMN09288185
# GCF_010509235.1 SAMN13925612
# GCF_016697425.1 SAMN16911570
# GCF_017504145.1 SAMN00138213
# GCF_017566105.1 SAMN14738317
# GCF_017570425.1 SAMN18309827
# GCF_017570485.1 SAMN18309825
# GCF_017570505.1 SAMN18309826
# GCF_017570525.1 SAMN18309824
# GCF_900184845.1 SAMEA104102601
# GCF_900184905.1 SAMEA104102612
# GCF_900184985.1 SAMEA104102607
# GCF_900185025.1 SAMEA104102606
# GCF_001683795.1 SAMN03840437
# GCF_900097105.1 SAMEA4378782
# GCF_900184965.1 SAMEA104102608
# biosample_descr_non_akk.tsv
# GCA_000155695.1 SAMN02436317
# GCA_000242935.3 SAMN02261410
# GCA_000243495.3 SAMN02261400
# GCA_000526255.1 SAMN02584925
# GCA_000739615.1 SAMD00036766
# GCA_000739655.1 SAMD00036768
# GCA_000972765.1 SAMN03452270
# GCA_001872735.1 SAMN04328238
# GCA_001897195.1 SAMN05660525
# GCA_002290545.1 SAMN06820743
# GCA_002291675.1 SAMN06455474
# GCA_002293145.1 SAMN06451665
# GCA_002304445.1 SAMN06820747
# GCA_002307065.1 SAMN06454786
# GCA_002323615.1 SAMN06456429
# GCA_002323895.1 SAMN06452620
# GCA_002323955.1 SAMN06452625
# GCA_002323995.1 SAMN06456430
# GCA_002344525.1 SAMN06451526
# GCA_002346535.1 SAMN06456355
# GCA_002364575.1 SAMN06451190
# GCA_002376875.1 SAMN06455295
# GCA_002388665.1 SAMN06455775
# GCA_002396485.1 SAMN06452429
# GCA_002420185.1 SAMN06457676
# GCA_002420305.1 SAMN06455115
# GCA_002420315.1 SAMN06455114
# GCA_002422425.1 SAMN06453817
# GCA_002428665.1 SAMN06452880
# GCA_002429005.1 SAMN06455369
# GCA_002429065.1 SAMN06455374
# GCA_002469895.1 SAMN06457656
# GCA_002500665.1 SAMN06451839
# GCA_002501065.1 SAMN06455358
# GCA_002686085.1 SAMN07620270
# GCA_002699365.1 SAMN07618560
# GCA_002713695.1 SAMN07619560
# GCA_002726915.1 SAMN07620205
# GCA_002729725.1 SAMN07619857
# GCA_002730975.1 SAMN07619570
# GCA_002771405.1 SAMN06659651
# GCA_002784415.1 SAMN06659844
# GCA_002791315.1 SAMN06660124
# GCA_003054655.1 SAMN08724137
# GCA_003054665.1 SAMN08724138
# GCA_003054695.1 SAMN08724136
# GCA_003131465.1 SAMN08179500
# GCA_003131485.1 SAMN08179498
# GCA_003134735.1 SAMN08179325
# GCA_003134765.1 SAMN08179315
# GCA_003134785.1 SAMN08179313
# GCA_003140255.1 SAMN08179124
# GCA_003142615.1 SAMN08180119
# GCA_003142955.1 SAMN08180081
# GCA_003151515.1 SAMN08179892
# GCA_003151575.1 SAMN08179889
# GCA_003164675.1 SAMN08179934
# GCA_003164715.1 SAMN08179932
# GCA_003167365.1 SAMN08178918
# GCA_003167555.1 SAMN08178892
# GCA_003167635.1 SAMN08178888
# GCA_003169695.1 SAMN08179111
# GCA_003169855.1 SAMN08179103
# GCA_003169975.1 SAMN08179093
# GCA_003170395.1 SAMN08179092
# GCA_003219195.1 SAMN08911969
# GCA_003219545.1 SAMN08911982
# GCA_003226295.1 SAMN09042165
# GCA_003558065.1 SAMN08574537
# GCA_003559525.1 SAMN08574493
# GCA_004293065.1 SAMN10167093
# GCA_004293105.1 SAMN10167089
# GCA_004293445.1 SAMN10167078
# GCA_004294095.1 SAMN10167050
# GCA_004321905.1 SAMN10720107
# GCA_005809105.1 SAMN11369443
# GCA_007119975.1 SAMN10606099
# GCA_007125965.1 SAMN10607148
# GCA_007129275.1 SAMN10606984
# GCA_007130045.1 SAMN10610685
# GCA_007133065.1 SAMN10610532
# GCA_007134215.1 SAMN10610477
# GCA_008080695.1 SAMN11532986
# GCA_008932965.1 SAMN09684548
# GCA_009772895.1 SAMN10737522
# GCA_009773355.1 SAMN11533007
# GCA_009885995.1 SAMN12036116
# GCA_009886045.1 SAMN12036114
# GCA_009936795.1 SAMN13828881
# GCA_009937095.1 SAMN13828870
# GCA_010500615.1 SAMN14001152
# GCA_010681825.2 SAMN14056161
# GCA_011047805.1 SAMN09639370
# GCA_011054375.1 SAMN09639233
# GCA_011058495.1 SAMN09639278
# GCA_011327725.1 SAMN09639624
# GCA_011327785.1 SAMN09639621
# GCA_011333855.1 SAMN09639970
# GCA_011362745.1 SAMN09639488
# GCA_011367605.1 SAMN09639679
# GCA_011368065.1 SAMN09639645
# GCA_011368315.1 SAMN09639610
# GCA_011525695.1 SAMN13738158
# GCA_012270205.1 SAMN12098052
# GCA_012517065.1 SAMN13894314
# GCA_012517205.1 SAMN13894308
# GCA_012959985.1 SAMN10967654
# GCA_012960505.1 SAMN10967627
# GCA_013041925.1 SAMN14538091
# GCA_013215165.1 SAMN14675768
# GCA_013391475.1 SAMN15363799
# GCA_013820875.1 SAMN15052335
# GCA_014193315.1 SAMD00166100
# GCA_014239365.1 SAMN14533092
# GCA_014381645.1 SAMN15784325
# GCA_014382585.1 SAMN15784277
# GCA_014529625.1 SAMN12856402
# GCA_014529665.1 SAMN12856396
# GCA_014529675.1 SAMN12856399
# GCA_014879535.1 SAMN12995740
# GCA_014879575.1 SAMN12995737
# GCA_014879935.1 SAMN12995720
# GCA_015075305.1 SAMN15013958
# GCA_015075365.1 SAMN15013953
# GCA_015659695.1 SAMN09926294
# GCA_015767365.1 SAMN16793119
# GCA_016187925.1 SAMN15434943
# GCA_016190985.1 SAMN15435119
# GCA_016195385.1 SAMN15435534
# GCA_016199985.1 SAMN15435690
# GCA_016217545.1 SAMN15436431
# GCA_016222805.1 SAMN15436807
# GCA_016222825.1 SAMN15436806
# GCA_016235555.1 SAMN15436645
# GCA_016462965.1 SAMN16655404
# GCA_016463145.1 SAMN16655394
# GCA_016595455.1 SAMN17169595
# GCA_016595575.1 SAMN17169588
# GCA_016713245.1 SAMN16425973
# GCA_016716505.1 SAMN16426159
# GCA_016777945.1 SAMN16436173
# GCA_016793645.1 SAMN17180891
# GCA_016793885.1 SAMN17180892
# GCA_016795365.1 SAMN17180901
# GCA_016795385.1 SAMN17180896
# GCA_016795425.1 SAMN17180894
# GCA_016795485.1 SAMN17180900
# GCA_016795505.1 SAMN17180895
# GCA_016795565.1 SAMN17180884
# GCA_016811075.1 SAMN17711332
# GCA_016871495.1 SAMN10967018
# GCA_016871535.1 SAMN10967012
# GCA_016871575.1 SAMN10967009
# GCA_016871755.1 SAMN10966996
# GCA_016871805.1 SAMN10966993
# GCA_016928295.1 SAMN17242028
# GCA_016935555.1 SAMN17243333
# GCA_017305195.1 SAMN18061515
# GCA_017309115.1 SAMN18059914
# GCA_900547395.1 SAMEA4891626
# GCA_900760665.1 SAMEA5279772
# GCA_900763545.1 SAMEA5279771
# GCA_903820035.1 SAMEA6944815
# GCA_903822625.1 SAMEA6944443
# GCA_903823585.1 SAMEA6946406
# GCA_903823955.1 SAMEA6950342
# GCA_903825655.1 SAMEA6956414
# GCA_903825845.1 SAMEA6943583
# GCA_903826105.1 SAMEA6946973
# GCA_903827225.1 SAMEA6949337
# GCA_903827245.1 SAMEA6949399
# GCA_903827375.1 SAMEA6949914
# GCA_903827955.1 SAMEA6954115
# GCA_903828255.1 SAMEA6954361
# GCA_903829895.1 SAMEA6947886
# GCA_903829915.1 SAMEA6947972
# GCA_903829935.1 SAMEA6947795
# GCA_903830045.1 SAMEA6948458
# GCA_903830155.1 SAMEA6945856
# GCA_903830425.1 SAMEA6949252
# GCA_903830575.1 SAMEA6949930
# GCA_903832615.1 SAMEA6947231
# GCA_903832955.1 SAMEA6945032
# GCA_903833605.1 SAMEA6946468
# GCA_903834135.1 SAMEA6951084
# GCA_903835255.1 SAMEA6955984
# GCA_903835285.1 SAMEA6956244
# GCA_903836245.1 SAMEA6948268
# GCA_903839375.1 SAMEA6953453
# GCA_903840355.1 SAMEA6943673
# GCA_903840415.1 SAMEA6944424
# GCA_903841665.1 SAMEA6950344
# GCA_903842505.1 SAMEA6952138
# GCA_903844265.1 SAMEA6950560
# GCA_903844885.1 SAMEA6954470
# GCA_903844915.1 SAMEA6954364
# GCA_903845515.1 SAMEA6944124
# GCA_903846165.1 SAMEA6945849
# GCA_903848695.1 SAMEA6946744
# GCA_903849065.1 SAMEA6945146
# GCA_903849435.1 SAMEA6945900
# GCA_903851165.1 SAMEA6955154
# GCA_903851485.1 SAMEA6956481
# GCA_903851505.1 SAMEA6956381
# GCA_903854255.1 SAMEA6954854
# GCA_903854295.1 SAMEA6955214
# GCA_903854475.1 SAMEA6956008
# GCA_903855995.1 SAMEA6947847
# GCA_903856725.1 SAMEA6948856
# GCA_903856775.1 SAMEA6948787
# GCA_903859495.1 SAMEA6944204
# GCA_903859715.1 SAMEA6946987
# GCA_903859905.1 SAMEA6944535
# GCA_903862025.1 SAMEA6949848
# GCA_903862405.1 SAMEA6953741
# GCA_903862595.1 SAMEA6951930
# GCA_903862765.1 SAMEA6954964
# GCA_903865455.1 SAMEA6947796
# GCA_903865745.1 SAMEA6948611
# GCA_903867105.1 SAMEA6944701
# GCA_903869175.1 SAMEA6948331
# GCA_903869675.1 SAMEA6951122
# GCA_903870255.1 SAMEA6955290
# GCA_903870815.1 SAMEA6947619
# GCA_903870895.1 SAMEA6945026
# GCA_903871035.1 SAMEA6948255
# GCA_903871185.1 SAMEA6948669
# GCA_903871215.1 SAMEA6948735
# GCA_903872345.1 SAMEA6946728
# GCA_903872885.1 SAMEA6946428
# GCA_903873415.1 SAMEA6954104
# GCA_903873795.1 SAMEA6955794
# GCA_903873945.1 SAMEA6956650
# GCA_903874045.1 SAMEA6944314
# GCA_903875465.1 SAMEA6955522
# GCA_903875675.1 SAMEA6944266
# GCA_903875685.1 SAMEA6944104
# GCA_903875755.1 SAMEA6944461
# GCA_903876035.1 SAMEA6947827
# GCA_903877055.1 SAMEA6955873
# GCA_903877135.1 SAMEA6955875
# GCA_903878115.1 SAMEA6951628
# GCA_903881465.1 SAMEA6955893
# GCA_903882455.1 SAMEA6950452
# GCA_903882875.1 SAMEA6954865
# GCA_903883725.1 SAMEA6949408
# GCA_903884295.1 SAMEA6954921
# GCA_903885235.1 SAMEA6950004
# GCA_903885245.1 SAMEA6949997
# GCA_903886895.1 SAMEA6951096
# GCA_903888785.1 SAMEA6943597
# GCA_903888925.1 SAMEA6946963
# GCA_903891145.1 SAMEA6954686
# GCA_903891255.1 SAMEA6955469
# GCA_903892385.1 SAMEA6951567
# GCA_903893265.1 SAMEA6949830
# GCA_903893885.1 SAMEA6955959
# GCA_903896015.1 SAMEA6947793
# GCA_903896365.1 SAMEA6949987
# GCA_903896505.1 SAMEA6953829
# GCA_903896705.1 SAMEA6954332
# GCA_903898185.1 SAMEA6947576
# GCA_903898675.1 SAMEA6954297
# GCA_903900845.1 SAMEA6952525
# GCA_903901425.1 SAMEA6946097
# GCA_903902115.1 SAMEA6944320
# GCA_903902745.1 SAMEA6954005
# GCA_903903235.1 SAMEA6944679
# GCA_903903695.1 SAMEA6952195
# GCA_903905115.1 SAMEA6945919
# GCA_903905305.1 SAMEA6950709
# GCA_903906515.1 SAMEA6956830
# GCA_903906645.1 SAMEA6944681
# GCA_903907025.1 SAMEA6951751
# GCA_903907925.1 SAMEA6955093
# GCA_903907995.1 SAMEA6955912
# GCA_903910895.1 SAMEA6949277
# GCA_903912925.1 SAMEA6947578
# GCA_903913865.1 SAMEA6951691
# GCA_903915115.1 SAMEA6954449
# GCA_903915855.1 SAMEA6944368
# GCA_903916085.1 SAMEA6954269
# GCA_903916625.1 SAMEA6951599
# GCA_903917335.1 SAMEA6945143
# GCA_903918605.1 SAMEA6952246
# GCA_903918755.1 SAMEA6944391
# GCA_903918885.1 SAMEA6947962
# GCA_903919125.1 SAMEA6956003
# GCA_903919175.1 SAMEA6944400
# GCA_903919975.1 SAMEA6951887
# GCA_903921715.1 SAMEA6954395
# GCA_903922605.1 SAMEA6947267
# GCA_903923245.1 SAMEA6956407
# GCA_903923255.1 SAMEA6955238
# GCA_903925145.1 SAMEA6948093
# GCA_903925935.1 SAMEA6953871
# GCA_903928105.1 SAMEA6955050
# GCA_903930345.1 SAMEA6951950
# GCA_903930415.1 SAMEA6956850
# GCA_903933715.1 SAMEA6946304
# GCA_903934285.1 SAMEA6945188
# GCA_903939515.1 SAMEA6949779
# GCA_903940805.1 SAMEA6951443
# GCA_903943535.1 SAMEA6945174
# GCA_903944655.1 SAMEA6948502
# GCA_903945405.1 SAMEA6945843
# GCA_903945705.1 SAMEA6950841
# GCA_903950355.1 SAMEA6950144
# GCA_903951815.1 SAMEA6945554
# GCA_903952285.1 SAMEA6949685
# GCA_903960095.1 SAMEA6946833
# GCA_904419695.1 SAMEA7202372
# GCA_904424815.1 SAMEA7306389
# GCA_905182405.1 SAMEA7768543
# GCA_905182465.1 SAMEA7768562
# GCA_905182475.1 SAMEA7768561
# GCA_905193115.1 SAMEA7846742
# GCA_905198945.1 SAMEA7846640
# GCA_905205865.1 SAMEA7846715
# GCF_000019665.1 SAMN02604183
# GCF_000019965.1 SAMN00000285
# GCF_000025905.1 SAMN02598501
# GCF_000171235.2 SAMN02256391
# GCF_000172155.1 SAMN02436175
# GCF_000172555.1 SAMN00000631
# GCF_000173075.1 SAMN00000678
# GCF_000297415.1 SAMEA2272587
# GCF_000378105.1 SAMN02441342
# GCF_000379365.1 SAMN02256457
# GCF_000817245.1 SAMN02996356
# GCF_001580015.1 SAMN04456986
# GCF_001580045.1 SAMN04456987
# GCF_001613545.1 SAMD00048637
# GCF_001746835.1 SAMN04880612
# GCF_002310495.1 SAMN07628394
# GCF_002954445.1 SAMN06090799
# GCF_003054705.1 SAMN08724139
# GCF_003185655.1 SAMN08997837
# GCF_004118375.1 SAMN10780907
# GCF_004341915.1 SAMN10866388
# GCF_004364345.1 SAMN02745162
# GCF_004421155.1 SAMN04957793
# GCF_004421165.1 SAMN04957802
# GCF_004421175.1 SAMN04957800
# GCF_004421185.1 SAMN04957807
# GCF_004421195.1 SAMN04932749
# GCF_004421255.1 SAMN04957809
# GCF_005780165.1 SAMN11569541
# GCF_007475525.1 SAMN08451303
# GCF_007559335.1 SAMN10623051
# GCF_007992435.1 SAMD00172670
# GCF_011044495.1 SAMN14143996
# GCF_011044775.1 SAMN14102279
# GCF_012913485.1 SAMN14642216
# GCF_014201715.1 SAMN14908355
# GCF_014230085.1 SAMN15676579
# GCF_014230145.1 SAMN15676578
# GCF_014651635.1 SAMD00245575
# GCF_014651675.1 SAMD00245577
# GCF_014803405.1 SAMN16205841
# GCF_016595415.1 SAMN17169596
# GCF_016595435.1 SAMN17169591
# GCF_016595465.1 SAMN17169592
# GCF_016595495.1 SAMN17169594
# GCF_016595505.1 SAMN17169593
# GCF_016595525.1 SAMN17169590
# GCF_016595555.1 SAMN17169589
# GCF_017310505.1 SAMN17036178
# GCF_017310525.1 SAMN17036247
# GCF_017310545.1 SAMN17073650
# GCF_900104925.1 SAMN05444173
# GCF_900105685.1 SAMN05444156
# GCF_900141815.1 SAMN02745181
# GCF_900167535.1 SAMN02745166
# GCF_902143375.2 SAMEA5600707
# GCF_902143385.2 SAMEA5600708
# GCF_902726575.1 SAMEA6101992
# GCF_902726585.1 SAMEA6101991
# GCF_902726595.1 SAMEA6101989
# GCF_902726605.1 SAMEA6101987
# GCF_902728225.1 SAMEA6101988
# GCF_902728235.1 SAMEA6101985
# GCF_902728245.1 SAMEA6101986
# GCF_902728255.1 SAMEA6101990

# %%
for f in des_files:
    ! wc -l $f
# Out:
# 180 biosample_descr_akk.tsv
# 384 biosample_descr_non_akk.tsv

# %% [markdown]
# ### For BioProject

# %%
# ! rm bioproject_descr_akk.tsv
# bp_descr = defaultdict()
# fh = open('bioproject_descr_akk.tsv', 'a')
# fh.write('Bioproject\tProject_Description\tProject_Name\tProject_Title\n')
# for idx,bp in ncbi_df.set_index('assembly_accession').loc[akk_ncbi.flatten(), :]['bioproject'].iteritems():
#     print(idx, bp)
# #     i += 1
# #     if i <100:
#     desc = ! esearch -db bioproject -query $bp | efetch -format docsum |  xtract -pattern DocumentSummary -element Project_Name,Project_Title,Project_Description
#     desc_ls = desc.get_spstr().split('\t')
#     desc_ls.insert(0, bp)
#     bp_descr[idx] = desc_ls
#     print('\t'.join(desc_ls), file=fh)
# fh.close()
# Out:
# GCA_000436395.1 PRJEB726
# GCA_000437075.1 PRJEB840
# GCA_001917295.1 PRJNA321218
# GCA_002362435.1 PRJNA348753
# GCA_002492685.1 PRJNA348753
# GCA_002493465.1 PRJNA348753
# GCA_003514565.1 PRJNA417962
# GCA_008672035.1 PRJNA492716
# GCA_008672205.1 PRJNA492716
# GCA_009773845.1 PRJNA544874
# GCA_014871965.1 PRJNA562766
# GCA_014871995.1 PRJNA562766
# GCA_014872005.1 PRJNA562766
# GCA_014872035.1 PRJNA562766
# GCA_014872065.1 PRJNA562766
# GCA_014872075.1 PRJNA562766
# GCA_014872105.1 PRJNA562766
# GCA_014872125.1 PRJNA562766
# GCA_014872165.1 PRJNA562766
# GCA_900539575.1 PRJEB26432
# GCA_900539895.1 PRJEB26432
# GCA_900545155.1 PRJEB26432
# GCA_900752515.1 PRJEB31003
# GCA_900759685.1 PRJEB31003
# GCA_900765745.1 PRJEB31003
# GCA_905193715.1 PRJEB37358
# GCA_905197035.1 PRJEB37358
# GCA_905200125.1 PRJEB37358
# GCA_905200945.1 PRJEB37358
# GCA_905205055.1 PRJEB37358
# GCA_905205915.1 PRJEB37358
# GCA_905210405.1 PRJEB37358
# GCA_905210615.1 PRJEB37358
# GCF_000020225.1 PRJNA224116
# GCF_000723745.2 PRJNA224116
# GCF_001578645.1 PRJNA224116
# GCF_001580195.1 PRJNA224116
# GCF_001647615.1 PRJNA224116
# GCF_001688765.2 PRJNA224116
# GCF_002161325.1 PRJNA224116
# GCF_002201495.1 PRJNA224116
# GCF_002884915.1 PRJNA224116
# GCF_002884975.1 PRJNA224116
# GCF_002884995.1 PRJNA224116
# GCF_002885015.1 PRJNA224116
# GCF_002885025.1 PRJNA224116
# GCF_002885055.1 PRJNA224116
# GCF_002885075.1 PRJNA224116
# GCF_002885095.1 PRJNA224116
# GCF_002885155.1 PRJNA224116
# GCF_002885165.1 PRJNA224116
# GCF_002885195.1 PRJNA224116
# GCF_002885215.1 PRJNA224116
# GCF_002885235.1 PRJNA224116
# GCF_002885255.1 PRJNA224116
# GCF_002885265.1 PRJNA224116
# GCF_002885295.1 PRJNA224116
# GCF_002885315.1 PRJNA224116
# GCF_002885335.1 PRJNA224116
# GCF_002885355.1 PRJNA224116
# GCF_002885375.1 PRJNA224116
# GCF_002885395.1 PRJNA224116
# GCF_002885415.1 PRJNA224116
# GCF_002885425.1 PRJNA224116
# GCF_002885455.1 PRJNA224116
# GCF_002885465.1 PRJNA224116
# GCF_002885515.1 PRJNA224116
# GCF_002885535.1 PRJNA224116
# GCF_002885575.1 PRJNA224116
# GCF_002885595.1 PRJNA224116
# GCF_002885615.1 PRJNA224116
# GCF_002885625.1 PRJNA224116
# GCF_002885655.1 PRJNA224116
# GCF_002885675.1 PRJNA224116
# GCF_002885695.1 PRJNA224116
# GCF_002885715.1 PRJNA224116
# GCF_003716915.1 PRJNA224116
# GCF_003716935.1 PRJNA224116
# GCF_003716955.1 PRJNA224116
# GCF_003716975.1 PRJNA224116
# GCF_004015005.1 PRJNA224116
# GCF_004015025.1 PRJNA224116
# GCF_004015045.1 PRJNA224116
# GCF_004015065.1 PRJNA224116
# GCF_004015085.1 PRJNA224116
# GCF_004015105.1 PRJNA224116
# GCF_004015125.1 PRJNA224116
# GCF_004015205.1 PRJNA224116
# GCF_004015225.1 PRJNA224116
# GCF_004015245.1 PRJNA224116
# GCF_004015265.1 PRJNA224116
# GCF_004015285.1 PRJNA224116
# GCF_004015305.1 PRJNA224116
# GCF_004015325.1 PRJNA224116
# GCF_004015345.1 PRJNA224116
# GCF_004104435.1 PRJNA224116
# GCF_004168105.1 PRJNA224116
# GCF_004319565.1 PRJNA224116
# GCF_008000975.1 PRJNA224116
# GCF_008422275.1 PRJNA224116
# GCF_008422615.1 PRJNA224116
# GCF_008422635.1 PRJNA224116
# GCF_008422665.1 PRJNA224116
# GCF_008422685.1 PRJNA224116
# GCF_008422695.1 PRJNA224116
# GCF_008422705.1 PRJNA224116
# GCF_008422715.1 PRJNA224116
# GCF_008422765.1 PRJNA224116
# GCF_008422775.1 PRJNA224116
# GCF_008422795.1 PRJNA224116
# GCF_008422805.1 PRJNA224116
# GCF_008422815.1 PRJNA224116
# GCF_008422865.1 PRJNA224116
# GCF_008422875.1 PRJNA224116
# GCF_008422885.1 PRJNA224116
# GCF_008422895.1 PRJNA224116
# GCF_008422925.1 PRJNA224116
# GCF_008422965.1 PRJNA224116
# GCF_008422985.1 PRJNA224116
# GCF_008422995.1 PRJNA224116
# GCF_008423015.1 PRJNA224116
# GCF_008423035.1 PRJNA224116
# GCF_008423065.1 PRJNA224116
# GCF_008423085.1 PRJNA224116
# GCF_008423095.1 PRJNA224116
# GCF_008423115.1 PRJNA224116
# GCF_008423135.1 PRJNA224116
# GCF_008423175.1 PRJNA224116
# GCF_008423185.1 PRJNA224116
# GCF_008423215.1 PRJNA224116
# GCF_008423245.1 PRJNA224116
# GCF_008423265.1 PRJNA224116
# GCF_008423275.1 PRJNA224116
# GCF_008423295.1 PRJNA224116
# GCF_008423325.1 PRJNA224116
# GCF_008423335.1 PRJNA224116
# GCF_008423365.1 PRJNA224116
# GCF_008423375.1 PRJNA224116
# GCF_008423385.1 PRJNA224116
# GCF_008423405.1 PRJNA224116
# GCF_008423445.1 PRJNA224116
# GCF_008423455.1 PRJNA224116
# GCF_009663785.1 PRJNA224116
# GCF_009731575.1 PRJNA224116
# GCF_010223015.1 PRJNA224116
# GCF_010223075.1 PRJNA224116
# GCF_010223095.1 PRJNA224116
# GCF_010223115.1 PRJNA224116
# GCF_010223135.1 PRJNA224116
# GCF_010223155.1 PRJNA224116
# GCF_010223175.1 PRJNA224116
# GCF_010223195.1 PRJNA224116
# GCF_010223255.1 PRJNA224116
# GCF_010223405.1 PRJNA224116
# GCF_010223575.1 PRJNA224116
# GCF_010229055.1 PRJNA224116
# GCF_010229495.1 PRJNA224116
# GCF_010229695.1 PRJNA224116
# GCF_010229955.1 PRJNA224116
# GCF_010230155.1 PRJNA224116
# GCF_010230375.1 PRJNA224116
# GCF_010230515.1 PRJNA224116
# GCF_010230725.1 PRJNA224116
# GCF_010230935.1 PRJNA224116
# GCF_010231195.1 PRJNA224116
# GCF_010509235.1 PRJNA224116
# GCF_016697425.1 PRJNA224116
# GCF_017504145.1 PRJNA224116
# GCF_017566105.1 PRJNA224116
# GCF_017570425.1 PRJNA224116
# GCF_017570485.1 PRJNA224116
# GCF_017570505.1 PRJNA224116
# GCF_017570525.1 PRJNA224116
# GCF_900184845.1 PRJNA224116
# GCF_900184905.1 PRJNA224116
# GCF_900184985.1 PRJNA224116
# GCF_900185025.1 PRJNA224116
# GCF_001683795.1 PRJNA224116
# GCF_900097105.1 PRJNA224116
# GCF_900184965.1 PRJNA224116

# %%
def add_info_to_summary(df = merged_df, col_to_write='host', *acc_to_animal):
    '''
    Add 'host' or 'type_of_sample' to the summary df. This information comes from grepping 
    the scientific and common species names or any other regex against the metadata 
    from biosample and bioproject.
    acc_to_anim : defaultdict/s with the form `genbank_acc:host_name`
    col_to_write= any col_name, but here should be 'host' or 'type_of_sample'
    '''
    import pandas as pd
    ncbi_genomes = df[df['Genome'].apply(lambda row: True if re.match('GCA|GCF', row) else False)]
    for dic in acc_to_animal:
        for i, row in ncbi_genomes.iterrows():
            acc = row.str.extract( '(GC[AF]_[0-9]{9}\.[1-9])')
            if acc.loc['Genome',][0] in dic.keys():
                df.loc[i, col_to_write] = dic[acc.loc['Genome',][0]]
    df.loc[:, col_to_write] = df[col_to_write].str.lower()
    print(df[col_to_write].value_counts())
    return 0


    
def build_line_source(biosample_meta, pattern, file_pattern=False):
    '''
    Returns the number of the line and the matched word. (ripgrep result)
    biosample_meta: samples description built with `efetch -db biosample`
    pattern: Regex or a file with patterns. E.g.: "'culture|soil|sludge|water|marine|biome'", 
    notice the 2 quotes, which are needed for complex patterns to work.
    file_pattern: Set it to True if a file with patterns is used. 
    '''
    
    import subprocess as sp
    from collections import defaultdict
    
    pattern = f'-f {pattern}' if file_pattern else pattern
    #uniq because one hit per line is enough
    rg_cmd = f"rg -woni {pattern} {biosample_meta} | sort -h | uniq"
    print(rg_cmd)
    line_animal = sp.check_output(rg_cmd, shell=True, universal_newlines=True)
    
    return line_animal


def build_acc_host(line_source, biosample_meta):
    '''
    For each line in the grip result (line_source), get the number of the line
    and use it to  get the line from the metadata/biosample descriptions. Then, build a 
    dictionary from ncbi accession to source/biome/host_animal.
    biosample_meta: samples description built with `efetch -db biosample`
    '''
    
    with open(biosample_meta, 'r') as fh:
        biosample_desc = fh.readlines()
        
    acc_to_source = defaultdict()
    for l in line_source.strip().split('\n'):
        # python list, `biosample_desc`. starts from 0
        n = int(l.split(':')[0]) - 1
        acc = biosample_desc[n].split('\t')[0]
        acc_to_source[acc] = l.split(':')[1].lower()
    print(len(acc_to_source))
    print('index for the list in python:', n)
    return acc_to_source

def build_acc_host_fromdict(line_source_dict, biosample_meta, source):
    '''
    Accepts a dictionary with line numbers as keys and list of sources as values.
    source: string, source to write in the table, e.g. 'marine water' 
    '''
    
    with open(biosample_meta, 'r') as fh:
        biosample_desc = fh.readlines()
        
    acc_to_source = defaultdict()
    for n in line_source_dict.keys():
        # python list, `biosample_desc`. starts from 0
        n = n - 1
        acc = biosample_desc[n].split('\t')[0]
        acc_to_source[acc] = source
    print(len(acc_to_source))
    print('index for the list in python:', n)
    return acc_to_source

# %% [markdown]
# ### Search in bioproject metadata

# %%
ln_meta_indicative_bp =  build_line_source('bioproject_descr_akk.tsv', "'stool|feces|gut|metagenome'", 
                                file_pattern=False)
print(ln_meta_indicative_bp[:100])
acc_meta_indicative_bp = build_acc_host(ln_meta_indicative_bp, 'biosample_descr_akk.tsv')
set(acc_meta_indicative_bp.values())
# Out:
# rg -woni 'stool|feces|gut|metagenome' bioproject_descr_akk.tsv | sort -h | uniq
# 2:gut
# 2:Gut
# 2:stool
# 3:gut
# 3:Gut
# 3:stool
# 4:gut
# 4:metagenome
# 8:metagenome
# 9:gut
# 9:metagenome
# 10:gut
# 10
# 29
# index for the list in python: 33
# {'metagenome', 'stool'}

# %%
acc_meta_indicative_bp
# Out:
# defaultdict(None,
#             {'GCA_000437075.1': 'stool',
#              'GCA_001917295.1': 'stool',
#              'GCA_002362435.1': 'metagenome',
#              'GCA_008672035.1': 'metagenome',
#              'GCA_008672205.1': 'metagenome',
#              'GCA_009773845.1': 'metagenome',
#              'GCA_014871995.1': 'metagenome',
#              'GCA_014872005.1': 'metagenome',
#              'GCA_014872035.1': 'metagenome',
#              'GCA_014872065.1': 'metagenome',
#              'GCA_014872075.1': 'metagenome',
#              'GCA_014872105.1': 'metagenome',
#              'GCA_014872125.1': 'metagenome',
#              'GCA_014872165.1': 'metagenome',
#              'GCA_900539575.1': 'metagenome',
#              'GCA_900539895.1': 'metagenome',
#              'GCA_900545155.1': 'metagenome',
#              'GCA_900752515.1': 'metagenome',
#              'GCA_900759685.1': 'metagenome',
#              'GCA_900765745.1': 'metagenome',
#              'GCA_905193715.1': 'metagenome',
#              'GCA_905197035.1': 'metagenome',
#              'GCA_905200125.1': 'metagenome',
#              'GCA_905200945.1': 'metagenome',
#              'GCA_905205055.1': 'metagenome',
#              'GCA_905205915.1': 'metagenome',
#              'GCA_905210405.1': 'metagenome',
#              'GCA_905210615.1': 'metagenome',
#              'GCF_000020225.1': 'metagenome'})

# %%
set(acc_meta_indicative_bp.keys()) - set(acc_culture.keys())
# Out:
# {'GCF_000020225.1'}

# %%
mask = ~merged_akk['relation_to_type_material'].isna()
merged_akk.loc[mask, 'type_of_sample'] = 'metagenome'

# %%
merged_akk.loc[~merged_akk['relation_to_type_material'].isna()]
# Out:
#                                    Genome  Completeness  Contamination  \
# 356     GCF_000020225.1_ASM2022v1_genomic         97.96           0.00
# 451   GCF_008000975.1_ASM800097v1_genomic         97.96           0.00
# 539  GCF_017504145.1_ASM1750414v1_genomic         97.96           0.00
# 580   GCF_001683795.1_ASM168379v1_genomic         91.84           4.76
#
#                                         classification  \
# 356  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 451  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 539  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 580  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
#
#                                  classification_method  sum_len      N50  \
# 356  taxonomic classification defined by topology a...  2664102  2664102
# 451  taxonomic classification defined by topology a...  2664043  2664043
# 539  taxonomic classification defined by topology a...  2664051  2664051
# 580  taxonomic classification defined by topology a...  3157849   127311
#
#      16S ribosomal RNA > 1400 nt  Total_tRNAs                host  \
# 356                          3.0           54                 NaN
# 451                          3.0           54        homo sapiens
# 539                          3.0           54                 NaN
# 580                          NaN           42  reticulated python
#
#                        NCBI_organism_name NCBI_infraspecific_name  \
# 356  Akkermansia muciniphila ATCC BAA-835     strain=ATCC BAA-835
# 451               Akkermansia muciniphila        strain=DSM 22959
# 539  Akkermansia muciniphila ATCC BAA-835     strain=ATCC BAA-835
# 580              Akkermansia glycaniphila              strain=Pyt
#
#        relation_to_type_material type_of_sample
# 356  assembly from type material     metagenome
# 451  assembly from type material     metagenome
# 539  assembly from type material     metagenome
# 580  assembly from type material     metagenome

# %% [markdown]
# # Set `host`

# %%
merged_df = pd.read_csv('/run/media/mibu/LR-orico_mini/Recovery_ADATA/Umayor/Work/Akker/Verrucomicrobia/QC/verrocu_seqs_summary.tsv', sep='\t')
merged_df.info()
print(merged_df['host'].value_counts(), merged_df['host'].isna().sum())
ln_comm_sp =  build_line_source('biosample_descr_akk.tsv', common_pats, file_pattern=True)
ln_sp =  build_line_source('biosample_descr_akk.tsv', sp_pats, file_pattern=True)
acc_comm_sp = build_acc_host(ln_comm_sp, 'biosample_descr_akk.tsv')
acc_sp = build_acc_host(ln_sp, 'biosample_descr_akk.tsv')
add_info_to_summary(merged_df, 'host', acc_comm_sp, acc_sp)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 585 entries, 0 to 584
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Genome                       585 non-null    object
#  1   Completeness                 585 non-null    float64
#  2   Contamination                585 non-null    float64
#  3   classification               585 non-null    object
#  4   classification_method        585 non-null    object
#  5   sum_len                      585 non-null    int64
#  6   N50                          585 non-null    int64
#  7   16S ribosomal RNA > 1400 nt  304 non-null    float64
#  8   Total_tRNAs                  585 non-null    int64
#  9   host                         8 non-null      object
#  10  NCBI_organism_name           212 non-null    object
#  11  NCBI_infraspecific_name      195 non-null    object
#  12  relation_to_type_material    40 non-null     object
# dtypes: float64(3), int64(3), object(7)
# memory usage: 59.5+ KB
# Mouse                  3
# Choloepus hoffmanni    1
# Diceros bicornis       1
# Bufo bufo              1
# Horse                  1
# Gallus gallus          1
# Name: host, dtype: int64 577
# rg -woni -f /home/mibu/common_names_ncbi.list biosample_descr_akk.tsv | sort -h | uniq
# rg -woni -f /home/mibu/amniota_only_sp.list biosample_descr_akk.tsv | sort -h | uniq
# 45
# index for the list in python: 177
# 123
# index for the list in python: 172
# homo sapiens           113
# human                   17
# mus musculus             9
# mouse                    4
# rat                      3
# gallus gallus            2
# reticulated python       1
# horse                    1
# diceros bicornis         1
# siamang                  1
# choloepus hoffmanni      1
# bufo bufo                1
# Name: host, dtype: int64
#                                                 Genome  Completeness  \
# 0              DGYMR06203__metabat2_low_PE.047.contigs         91.12
# 1    F157a_European_Toad__metabat2_high_PE.005.contigs         89.32
# 2                   GCA_000155695.1_ASM15569v1_genomic        100.00
# 3                   GCA_000242935.3_ASM24293v3_genomic        100.00
# 4                   GCA_000243495.3_ASM24349v3_genomic         98.63
# ..                                                 ...           ...
# 580                GCF_001683795.1_ASM168379v1_genomic         91.84
# 581                      GCF_900097105.1_WK001_genomic         93.88
# 582           GCF_900184965.1_Mouse_2_MG.fasta_genomic         97.96
# 583                                           MGG23710         97.96
# 584                                           MGG28571         96.60
#
#      Contamination                                     classification  \
# 0             0.00  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 1             2.30  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 2             1.35  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 3             0.23  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 4             0.23  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# ..             ...                                                ...
# 580           4.76  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 581           0.68  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 582           1.36  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 583           0.00  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 584           0.00  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
#
#                                  classification_method  sum_len      N50  \
# 0    taxonomic classification defined by topology a...  2417897    26278
# 1    taxonomic classification defined by topology a...  2029501     8457
# 2    taxonomic classification defined by topology a...  5775745  5514226
# 3    taxonomic classification defined by topology a...  7417673  7317842
# 4    taxonomic classification defined by topology a...  7073483  6196881
# ..                                                 ...      ...      ...
# 580  taxonomic classification defined by topology a...  3157849   127311
# 581  taxonomic classification defined by topology a...  2768865     1326
# 582  taxonomic classification defined by topology a...  2837147   181108
# 583  taxonomic classification defined by topology a...  2888964   250634
# 584  taxonomic classification defined by topology a...  2937955    79240
#
#      16S ribosomal RNA > 1400 nt  Total_tRNAs                host  \
# 0                            NaN           44       gallus gallus
# 1                            NaN           40           bufo bufo
# 2                            1.0           45                 NaN
# 3                            1.0           52                 NaN
# 4                            1.0           71                 NaN
# ..                           ...          ...                 ...
# 580                          NaN           42  reticulated python
# 581                          0.0            0                 NaN
# 582                          NaN           48               mouse
# 583                          NaN           48               mouse
# 584                          NaN           44               mouse
#
#            NCBI_organism_name NCBI_infraspecific_name  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
# ..                        ...                     ...
# 580  Akkermansia glycaniphila              strain=Pyt
# 581  Akkermansia glycaniphila                     NaN
# 582   Akkermansia muciniphila                     NaN
# 583                       NaN                     NaN
# 584                       NaN                     NaN
#
#        relation_to_type_material
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 580  assembly from type material
# 581                          NaN
# 582                          NaN
# 583                          NaN
# 584                          NaN
#
# [585 rows x 13 columns]

# %%
merged_df['host'] = merged_df['host'].str.lower()
common_to_sp  = {'mice':'mus musculus','mouse':'mus musculus', 'human':'homo sapiens', 'jasper':'unknown'}
merged_df['host'].replace(common_to_sp, inplace=True)

# %%
merged_df['host'].value_counts()
# Out:
# homo sapiens           130
# mus musculus            13
# rat                      3
# gallus gallus            2
# reticulated python       1
# horse                    1
# diceros bicornis         1
# siamang                  1
# choloepus hoffmanni      1
# bufo bufo                1
# Name: host, dtype: int64

# %% [markdown]
# # End `host`

# %% [markdown]
# # Set `type_of_sample`

# %%
ln_culture =  build_line_source('biosample_descr_akk.tsv', "'culture|cultured|isolate|isolated|metagenome|monoisolate|uncultured'", 
                                file_pattern=False)
print(ln_culture[:100])
acc_culture = build_acc_host(ln_culture, 'biosample_descr_akk.tsv')
print(set(acc_culture.values()))
# Out:
# rg -woni 'culture|cultured|isolate|isolated|metagenome|monoisolate|uncultured' biosample_descr_akk.tsv | sort -h | uniq
# 1:metagenome
# 2:metagenome
# 3:metagenome
# 4:metagenome
# 5:metagenome
# 6:metagenome
# 7:metagenome
# 8:metagen
# 80
# index for the list in python: 165
# {'uncultured', 'isolate', 'culture', 'metagenome'}

# %%
add_info_to_summary(merged_df,'type_of_sample', acc_culture)
# merged_df['type_of_sample'].value_counts()
# Out:
# culture       42
# metagenome    30
# isolate        5
# uncultured     3
# Name: type_of_sample, dtype: int64
#                                                 Genome  Completeness  \
# 0              DGYMR06203__metabat2_low_PE.047.contigs         91.12
# 1    F157a_European_Toad__metabat2_high_PE.005.contigs         89.32
# 2                   GCA_000155695.1_ASM15569v1_genomic        100.00
# 3                   GCA_000242935.3_ASM24293v3_genomic        100.00
# 4                   GCA_000243495.3_ASM24349v3_genomic         98.63
# ..                                                 ...           ...
# 580                GCF_001683795.1_ASM168379v1_genomic         91.84
# 581                      GCF_900097105.1_WK001_genomic         93.88
# 582           GCF_900184965.1_Mouse_2_MG.fasta_genomic         97.96
# 583                                           MGG23710         97.96
# 584                                           MGG28571         96.60
#
#      Contamination                                     classification  \
# 0             0.00  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 1             2.30  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 2             1.35  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 3             0.23  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 4             0.23  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# ..             ...                                                ...
# 580           4.76  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 581           0.68  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 582           1.36  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 583           0.00  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 584           0.00  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
#
#                                  classification_method  sum_len      N50  \
# 0    taxonomic classification defined by topology a...  2417897    26278
# 1    taxonomic classification defined by topology a...  2029501     8457
# 2    taxonomic classification defined by topology a...  5775745  5514226
# 3    taxonomic classification defined by topology a...  7417673  7317842
# 4    taxonomic classification defined by topology a...  7073483  6196881
# ..                                                 ...      ...      ...
# 580  taxonomic classification defined by topology a...  3157849   127311
# 581  taxonomic classification defined by topology a...  2768865     1326
# 582  taxonomic classification defined by topology a...  2837147   181108
# 583  taxonomic classification defined by topology a...  2888964   250634
# 584  taxonomic classification defined by topology a...  2937955    79240
#
#      16S ribosomal RNA > 1400 nt  Total_tRNAs                host  \
# 0                            NaN           44       gallus gallus
# 1                            NaN           40           bufo bufo
# 2                            1.0           45                 NaN
# 3                            1.0           52                 NaN
# 4                            1.0           71                 NaN
# ..                           ...          ...                 ...
# 580                          NaN           42  reticulated python
# 581                          0.0            0                 NaN
# 582                          NaN           48        mus musculus
# 583                          NaN           48        mus musculus
# 584                          NaN           44        mus musculus
#
#            NCBI_organism_name NCBI_infraspecific_name  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
# ..                        ...                     ...
# 580  Akkermansia glycaniphila              strain=Pyt
# 581  Akkermansia glycaniphila                     NaN
# 582   Akkermansia muciniphila                     NaN
# 583                       NaN                     NaN
# 584                       NaN                     NaN
#
#        relation_to_type_material type_of_sample
# 0                            NaN            NaN
# 1                            NaN            NaN
# 2                            NaN            NaN
# 3                            NaN            NaN
# 4                            NaN            NaN
# ..                           ...            ...
# 580  assembly from type material            NaN
# 581                          NaN            NaN
# 582                          NaN            NaN
# 583                          NaN            NaN
# 584                          NaN            NaN
#
# [585 rows x 14 columns]

# %%
common_to_sp  = {'isolate':'culture', 'uncultured':'metagenome'}
merged_df['type_of_sample'].replace(common_to_sp, inplace=True)
merged_df['type_of_sample'].value_counts(), merged_df['type_of_sample'].isna().sum()
# Out:
# (culture       47
#  metagenome    33
#  Name: type_of_sample, dtype: int64,
#  505)

# %% [markdown]
# ## Add `culture` to all the non-NAs values in `relation_to_type_material`

# %%
merged_akk = merged_df[merged_df['classification'].str.contains('g__Akkermansia')].copy()
merged_akk['type_of_sample'].value_counts(), merged_akk['type_of_sample'].isna().sum()
# Out:
# (culture       47
#  metagenome    33
#  Name: type_of_sample, dtype: int64,
#  121)

# %%
mask = ~merged_akk['relation_to_type_material'].isna()
merged_akk.loc[mask, 'type_of_sample'] = 'culture'

# %%
merged_akk.loc[~merged_akk['relation_to_type_material'].isna()]
# Out:
#                                    Genome  Completeness  Contamination  \
# 356     GCF_000020225.1_ASM2022v1_genomic         97.96           0.00
# 451   GCF_008000975.1_ASM800097v1_genomic         97.96           0.00
# 539  GCF_017504145.1_ASM1750414v1_genomic         97.96           0.00
# 580   GCF_001683795.1_ASM168379v1_genomic         91.84           4.76
#
#                                         classification  \
# 356  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 451  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 539  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 580  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
#
#                                  classification_method  sum_len      N50  \
# 356  taxonomic classification defined by topology a...  2664102  2664102
# 451  taxonomic classification defined by topology a...  2664043  2664043
# 539  taxonomic classification defined by topology a...  2664051  2664051
# 580  taxonomic classification defined by topology a...  3157849   127311
#
#      16S ribosomal RNA > 1400 nt  Total_tRNAs                host  \
# 356                          3.0           54                 NaN
# 451                          3.0           54        homo sapiens
# 539                          3.0           54                 NaN
# 580                          NaN           42  reticulated python
#
#                        NCBI_organism_name NCBI_infraspecific_name  \
# 356  Akkermansia muciniphila ATCC BAA-835     strain=ATCC BAA-835
# 451               Akkermansia muciniphila        strain=DSM 22959
# 539  Akkermansia muciniphila ATCC BAA-835     strain=ATCC BAA-835
# 580              Akkermansia glycaniphila              strain=Pyt
#
#        relation_to_type_material type_of_sample
# 356  assembly from type material        culture
# 451  assembly from type material        culture
# 539  assembly from type material        culture
# 580  assembly from type material        culture

# %%
merged_akk.to_csv(qc_path.joinpath('merged_akk.tsv'), sep='\t', index=False)c

# %% [markdown]
# # End `type_of_sample`

# %% [markdown]
# # Which asms are in the 'indicative' but no in the 'culture dict' ?

# %%
ln_meta_indicative =  build_line_source('biosample_descr_akk.tsv', "'stool|feces|gut|fecal|biome|microbiome'", 
                                file_pattern=False)
print(ln_meta_indicative[:100])
acc_meta_indicative = build_acc_host(ln_meta_indicative, 'biosample_descr_akk.tsv')
# acc_meta_indicative
# Out:
# rg -woni 'stool|feces|gut|fecal|biome|microbiome' biosample_descr_akk.tsv | sort -h | uniq
# 1:gut
# 2:gut
# 3:gut
# 4:gut
# 5:gut
# 6:gut
# 8:biome
# 8:feces
# 8:gut
# 9:biome
# 9:feces
# 9:gut
# 10:feces
# 11:feces
# 11
# 163
# index for the list in python: 177

# %%
set(acc_culture.keys()) - set(acc_meta_indicative.keys()), set(acc_meta_indicative.keys()) - set(acc_culture.keys())
# Out:
# ({'GCA_003514565.1', 'GCF_004319565.1'},
#  {'GCF_001580195.1',
#   'GCF_001683795.1',
#   'GCF_002884915.1',
#   'GCF_002884995.1',
#   'GCF_002885015.1',
#   'GCF_002885025.1',
#   'GCF_002885055.1',
#   'GCF_002885075.1',
#   'GCF_002885155.1',
#   'GCF_002885165.1',
#   'GCF_002885195.1',
#   'GCF_002885215.1',
#   'GCF_002885235.1',
#   'GCF_002885255.1',
#   'GCF_002885295.1',
#   'GCF_002885315.1',
#   'GCF_002885335.1',
#   'GCF_002885355.1',
#   'GCF_002885375.1',
#   'GCF_002885395.1',
#   'GCF_002885415.1',
#   'GCF_002885425.1',
#   'GCF_002885455.1',
#   'GCF_002885465.1',
#   'GCF_002885515.1',
#   'GCF_002885535.1',
#   'GCF_002885575.1',
#   'GCF_002885595.1',
#   'GCF_002885615.1',
#   'GCF_002885625.1',
#   'GCF_002885655.1',
#   'GCF_002885675.1',
#   'GCF_002885695.1',
#   'GCF_002885715.1',
#   'GCF_004104435.1',
#   'GCF_004168105.1',
#   'GCF_008422275.1',
#   'GCF_008422615.1',
#   'GCF_008422635.1',
#   'GCF_008422665.1',
#   'GCF_008422685.1',
#   'GCF_008422695.1',
#   'GCF_008422705.1',
#   'GCF_008422715.1',
#   'GCF_008422765.1',
#   'GCF_008422775.1',
#   'GCF_008422795.1',
#   'GCF_008422805.1',
#   'GCF_008422815.1',
#   'GCF_008422865.1',
#   'GCF_008422875.1',
#   'GCF_008422885.1',
#   'GCF_008422895.1',
#   'GCF_008422925.1',
#   'GCF_008422965.1',
#   'GCF_008422985.1',
#   'GCF_008422995.1',
#   'GCF_008423015.1',
#   'GCF_008423035.1',
#   'GCF_008423065.1',
#   'GCF_008423085.1',
#   'GCF_008423095.1',
#   'GCF_008423115.1',
#   'GCF_008423135.1',
#   'GCF_008423175.1',
#   'GCF_008423185.1',
#   'GCF_008423215.1',
#   'GCF_008423245.1',
#   'GCF_008423265.1',
#   'GCF_008423275.1',
#   'GCF_008423295.1',
#   'GCF_008423325.1',
#   'GCF_008423335.1',
#   'GCF_008423365.1',
#   'GCF_008423375.1',
#   'GCF_008423385.1',
#   'GCF_008423405.1',
#   'GCF_008423445.1',
#   'GCF_008423455.1',
#   'GCF_016697425.1',
#   'GCF_017566105.1',
#   'GCF_017570425.1',
#   'GCF_017570485.1',
#   'GCF_017570505.1',
#   'GCF_017570525.1'})

# %%
merged_akk['type_of_sample'].value_counts(), merged_akk['type_of_sample'].isna().sum()
# Out:
# (metagenome    74
#  culture       50
#  Name: type_of_sample, dtype: int64,
#  77)

# %% [markdown]
# ## Get all the asms that aren't `culture` but are "indicative" and set them to `metagenome`

# %%
acc_not_culture = (merged_akk[~(merged_akk['type_of_sample'] == 'culture')]['Genome'].
                   str.extract( '(GC[AF]_[0-9]{9}\.[1-9])').dropna().values.flatten())
acc_not_culture[:10]
# Out:
# array(['GCA_000436395.1', 'GCA_000437075.1', 'GCA_001917295.1',
#        'GCA_002362435.1', 'GCA_002492685.1', 'GCA_002493465.1',
#        'GCA_003514565.1', 'GCA_008672035.1', 'GCA_008672205.1',
#        'GCA_009773845.1'], dtype=object)

# %%
acc_meta_indicat_notcult = {asm:source for asm,source in acc_meta_indicative.items() if asm in acc_not_culture}
len(acc_meta_indicat_notcult), len(acc_meta_indicative)
# Out:
# (116, 163)

# %%
acc_meta_indicat_notcult
# Out:
# {'GCA_000436395.1': 'gut',
#  'GCA_000437075.1': 'gut',
#  'GCA_001917295.1': 'gut',
#  'GCA_002362435.1': 'gut',
#  'GCA_002492685.1': 'gut',
#  'GCA_002493465.1': 'gut',
#  'GCA_008672035.1': 'gut',
#  'GCA_008672205.1': 'gut',
#  'GCA_009773845.1': 'feces',
#  'GCA_014871965.1': 'gut',
#  'GCA_014871995.1': 'gut',
#  'GCA_014872005.1': 'gut',
#  'GCA_014872035.1': 'gut',
#  'GCA_014872065.1': 'gut',
#  'GCA_014872075.1': 'gut',
#  'GCA_014872105.1': 'gut',
#  'GCA_014872125.1': 'gut',
#  'GCA_014872165.1': 'gut',
#  'GCA_900539575.1': 'gut',
#  'GCA_900539895.1': 'gut',
#  'GCA_900545155.1': 'gut',
#  'GCA_900752515.1': 'stool',
#  'GCA_900759685.1': 'stool',
#  'GCA_900765745.1': 'stool',
#  'GCA_905193715.1': 'gut',
#  'GCA_905197035.1': 'gut',
#  'GCA_905200125.1': 'gut',
#  'GCA_905200945.1': 'gut',
#  'GCA_905205055.1': 'gut',
#  'GCA_905205915.1': 'gut',
#  'GCA_905210405.1': 'gut',
#  'GCA_905210615.1': 'gut',
#  'GCF_001580195.1': 'feces',
#  'GCF_002884915.1': 'gut',
#  'GCF_002884995.1': 'gut',
#  'GCF_002885015.1': 'gut',
#  'GCF_002885025.1': 'gut',
#  'GCF_002885055.1': 'gut',
#  'GCF_002885075.1': 'gut',
#  'GCF_002885155.1': 'gut',
#  'GCF_002885165.1': 'gut',
#  'GCF_002885195.1': 'gut',
#  'GCF_002885215.1': 'gut',
#  'GCF_002885235.1': 'gut',
#  'GCF_002885255.1': 'gut',
#  'GCF_002885295.1': 'gut',
#  'GCF_002885315.1': 'gut',
#  'GCF_002885335.1': 'gut',
#  'GCF_002885355.1': 'gut',
#  'GCF_002885375.1': 'gut',
#  'GCF_002885395.1': 'gut',
#  'GCF_002885415.1': 'gut',
#  'GCF_002885425.1': 'gut',
#  'GCF_002885455.1': 'gut',
#  'GCF_002885465.1': 'gut',
#  'GCF_002885515.1': 'gut',
#  'GCF_002885535.1': 'gut',
#  'GCF_002885575.1': 'gut',
#  'GCF_002885595.1': 'gut',
#  'GCF_002885615.1': 'gut',
#  'GCF_002885625.1': 'gut',
#  'GCF_002885655.1': 'gut',
#  'GCF_002885675.1': 'gut',
#  'GCF_002885695.1': 'gut',
#  'GCF_002885715.1': 'gut',
#  'GCF_004104435.1': 'gut',
#  'GCF_004168105.1': 'stool',
#  'GCF_008422275.1': 'fecal',
#  'GCF_008422615.1': 'fecal',
#  'GCF_008422635.1': 'fecal',
#  'GCF_008422665.1': 'fecal',
#  'GCF_008422685.1': 'fecal',
#  'GCF_008422695.1': 'fecal',
#  'GCF_008422705.1': 'fecal',
#  'GCF_008422715.1': 'fecal',
#  'GCF_008422765.1': 'fecal',
#  'GCF_008422775.1': 'fecal',
#  'GCF_008422795.1': 'fecal',
#  'GCF_008422805.1': 'fecal',
#  'GCF_008422815.1': 'fecal',
#  'GCF_008422865.1': 'fecal',
#  'GCF_008422875.1': 'fecal',
#  'GCF_008422885.1': 'fecal',
#  'GCF_008422895.1': 'fecal',
#  'GCF_008422925.1': 'fecal',
#  'GCF_008422965.1': 'fecal',
#  'GCF_008422985.1': 'fecal',
#  'GCF_008422995.1': 'fecal',
#  'GCF_008423015.1': 'fecal',
#  'GCF_008423035.1': 'fecal',
#  'GCF_008423065.1': 'fecal',
#  'GCF_008423085.1': 'fecal',
#  'GCF_008423095.1': 'fecal',
#  'GCF_008423115.1': 'fecal',
#  'GCF_008423135.1': 'fecal',
#  'GCF_008423175.1': 'fecal',
#  'GCF_008423185.1': 'fecal',
#  'GCF_008423215.1': 'fecal',
#  'GCF_008423245.1': 'fecal',
#  'GCF_008423265.1': 'fecal',
#  'GCF_008423275.1': 'fecal',
#  'GCF_008423295.1': 'fecal',
#  'GCF_008423325.1': 'fecal',
#  'GCF_008423335.1': 'fecal',
#  'GCF_008423365.1': 'fecal',
#  'GCF_008423375.1': 'fecal',
#  'GCF_008423385.1': 'fecal',
#  'GCF_008423405.1': 'fecal',
#  'GCF_008423445.1': 'fecal',
#  'GCF_008423455.1': 'fecal',
#  'GCF_016697425.1': 'gut',
#  'GCF_017566105.1': 'stool',
#  'GCF_017570425.1': 'gut',
#  'GCF_017570485.1': 'gut',
#  'GCF_017570505.1': 'gut',
#  'GCF_017570525.1': 'gut'}

# %%
add_info_to_summary(merged_akk,'type_of_sample', acc_meta_indicat_notcult)
# Out:
# gut           66
# culture       50
# fecal         43
# stool          5
# feces          2
# metagenome     1
# Name: type_of_sample, dtype: int64
#                                                 Genome  Completeness  \
# 0              DGYMR06203__metabat2_low_PE.047.contigs         91.12
# 1    F157a_European_Toad__metabat2_high_PE.005.contigs         89.32
# 5                       GCA_000436395.1_MGS154_genomic         95.07
# 6                       GCA_000437075.1_MGS344_genomic         97.25
# 13                 GCA_001917295.1_ASM191729v1_genomic         97.28
# ..                                                 ...           ...
# 580                GCF_001683795.1_ASM168379v1_genomic         91.84
# 581                      GCF_900097105.1_WK001_genomic         93.88
# 582           GCF_900184965.1_Mouse_2_MG.fasta_genomic         97.96
# 583                                           MGG23710         97.96
# 584                                           MGG28571         96.60
#
#      Contamination                                     classification  \
# 0             0.00  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 1             2.30  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 5             0.00  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 6             1.36  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 13            0.00  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# ..             ...                                                ...
# 580           4.76  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 581           0.68  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 582           1.36  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 583           0.00  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 584           0.00  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
#
#                                  classification_method  sum_len     N50  \
# 0    taxonomic classification defined by topology a...  2417897   26278
# 1    taxonomic classification defined by topology a...  2029501    8457
# 5    taxonomic classification defined by topology a...  2721828   74342
# 6    taxonomic classification defined by topology a...  3024253  170254
# 13   taxonomic classification defined by topology a...  2966498  183307
# ..                                                 ...      ...     ...
# 580  taxonomic classification defined by topology a...  3157849  127311
# 581  taxonomic classification defined by topology a...  2768865    1326
# 582  taxonomic classification defined by topology a...  2837147  181108
# 583  taxonomic classification defined by topology a...  2888964  250634
# 584  taxonomic classification defined by topology a...  2937955   79240
#
#      16S ribosomal RNA > 1400 nt  Total_tRNAs                host  \
# 0                            NaN           44       gallus gallus
# 1                            NaN           40           bufo bufo
# 5                            NaN           46        homo sapiens
# 6                            NaN           50        homo sapiens
# 13                           NaN           47        homo sapiens
# ..                           ...          ...                 ...
# 580                          NaN           42  reticulated python
# 581                          0.0            0                 NaN
# 582                          NaN           48        mus musculus
# 583                          NaN           48        mus musculus
# 584                          NaN           44        mus musculus
#
#            NCBI_organism_name NCBI_infraspecific_name  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 5                         NaN                     NaN
# 6                         NaN                     NaN
# 13                        NaN                     NaN
# ..                        ...                     ...
# 580  Akkermansia glycaniphila              strain=Pyt
# 581  Akkermansia glycaniphila                     NaN
# 582   Akkermansia muciniphila                     NaN
# 583                       NaN                     NaN
# 584                       NaN                     NaN
#
#        relation_to_type_material type_of_sample
# 0                            NaN            NaN
# 1                            NaN            NaN
# 5                            NaN            gut
# 6                            NaN            gut
# 13                           NaN            gut
# ..                           ...            ...
# 580  assembly from type material        culture
# 581                          NaN            NaN
# 582                          NaN            NaN
# 583                          NaN            NaN
# 584                          NaN            NaN
#
# [201 rows x 14 columns]

# %%
merged_akk['type_of_sample'].value_counts(), merged_akk['type_of_sample'].isna().sum()
# Out:
# (gut           66
#  culture       50
#  fecal         43
#  stool          5
#  feces          2
#  metagenome     1
#  Name: type_of_sample, dtype: int64,
#  34)

# %%
common_to_sp  = {'gut':'metagenome', 'feces':'metagenome','fecal':'metagenome',
                 'stool':'metagenome'}
merged_akk['type_of_sample'].replace(common_to_sp, inplace=True)
merged_akk['type_of_sample'].value_counts()
# Out:
# metagenome    117
# culture        50
# Name: type_of_sample, dtype: int64

# %%
merged_akk.to_csv(qc_path.joinpath('merged_akk.tsv'), sep='\t', index=False)

# %%
# build_acc_host(line_biome_all, sample_desc_all)
ln = {int(el.split(':')[0]) for el in ln_culture.strip().split('\n')}
ln_notpresent = [el for el in range(1,181) if el not in ln]
print(ln_notpresent, len(ln_notpresent))
# for el in line_biome_all.split('\n'):
# Out:
# [34, 35, 37, 38, 39, 40, 41, 42, 44, 45, 46, 47, 48, 50, 51, 52, 53, 54, 55, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 96, 97, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180] 100

# %%
with open('biosample_descr_akk.tsv', 'r') as fh:
    biosample_akk_desc = fh.readlines()

with open('bioproject_descr_akk.tsv', 'r') as fh:
    bioproj_akk_desc = fh.readlines()
print(len(biosample_akk_desc), len(bioproj_akk_desc))
# Out:
# 180 181

# %%
for ln in ln_notpresent:
    print(biosample_akk_desc[ln-1])
# Out:
# GCF_000020225.1	SAMN00138213	ATCC BAA-835
#
# GCF_000723745.2	SAMEA3139045	GCA_000723745	European Nucleotide Archive	ERC000011	EBI	European Bioinformatics Institute	2014-11-20T12:20:15Z	2014-11-20T11:56:31Z	public	ERS610980	ERS610980	BioSample entry for genome collection GCA_000723745	Urmite
#
# GCF_001580195.1	SAMN03956447	feces	Homo sapiens	KLE1798
#
# GCF_001647615.1	SAMN04606485	GI tract	KLE1605	Homo sapiens	High-Quality Draft	High-Quality Draft	Velvet v. 1.1.04	128x	Illumina
#
# GCF_001688765.2	SAMN04621615	YL44	Mus musculus	2015-02-26	Switzerland: Bern	whole organism
#
# GCF_002161325.1	SAMN06473757	healthy	missing	not applicable	missing	not applicable	Gallus gallus	not applicable	not applicable	commensal	caecum	An78	anaerobe	caecum	2016	not applicable	missing
#
# GCF_002201495.1	SAMN03854119	YL44	Switzerland: Zurich	not applicable	not applicable	not applicable	organic feature	intestine environment	47 N 8 E	organic material	not applicable	Mus musculus	DSM:26127
#
# GCF_002884915.1	SAMN08162557	GP24	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002884995.1	SAMN08162554	GP30	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885015.1	SAMN08162551	GP12	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885025.1	SAMN08162552	GP15	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885055.1	SAMN08162550	GP11	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885075.1	SAMN08162548	GP08	Mus musculus	gut microbiota	2015	China	assembly
#
# GCF_002885155.1	SAMN08162544	GP43	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885165.1	SAMN08162543	GP41	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885195.1	SAMN08162540	GP36	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885215.1	SAMN08162539	GP29	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885235.1	SAMN08162538	GP21	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885255.1	SAMN08162534	GP03	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885295.1	SAMN08162531	GP35	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885315.1	SAMN08162529	GP27	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885335.1	SAMN08162528	GP26	Mus musculus	gut microbiota	2015	China	assembly
#
# GCF_002885355.1	SAMN08162527	GP23	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885375.1	SAMN08162526	GP20	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885395.1	SAMN08162525	GP19	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885415.1	SAMN08162524	GP16	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885425.1	SAMN08162523	GP14	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885455.1	SAMN08162522	GP13	Mus musculus	gut microbiota	2015	China	assembly
#
# GCF_002885465.1	SAMN08162520	GP02	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885515.1	SAMN08162555	GP42	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885535.1	SAMN08162553	GP25	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885575.1	SAMN08162542	GP39	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885595.1	SAMN08162541	GP38	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885615.1	SAMN08162537	GP06	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885625.1	SAMN08162536	GP05	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885655.1	SAMN08162535	GP04	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885675.1	SAMN08162532	GP40	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885695.1	SAMN08162530	GP28	Homo sapiens	gut microbiota	2015	China	assembly
#
# GCF_002885715.1	SAMN08162521	GP09	Mus musculus	gut microbiota	2015	China	assembly
#
# GCF_004104435.1	SAMN10186677	CBA5201	missing	missing	missing	human-gut	missing	Homo sapiens	missing	missing	missing	missing	human feces
#
# GCF_004168105.1	SAMN10239579	am_0171	Homo sapiens	stool	2015-01	USA: Cambridge	OpenBiome Stol
#
# GCF_008422275.1	SAMN11943062	BIOML-A17	2014-07-04	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422615.1	SAMN11943045	BIOML-A45	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422635.1	SAMN11943044	BIOML-A44	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422665.1	SAMN11943043	BIOML-A43	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422685.1	SAMN11943039	BIOML-A39	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422695.1	SAMN11943041	BIOML-A41	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422705.1	SAMN11943040	BIOML-A40	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422715.1	SAMN11943042	BIOML-A42	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422765.1	SAMN11943036	BIOML-A36	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422775.1	SAMN11943037	BIOML-A37	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422795.1	SAMN11943035	BIOML-A35	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422805.1	SAMN11943034	BIOML-A34	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422815.1	SAMN11943038	BIOML-A38	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422865.1	SAMN11943032	BIOML-A32	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422875.1	SAMN11943030	BIOML-A30	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422885.1	SAMN11943033	BIOML-A33	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422895.1	SAMN11943031	BIOML-A31	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422925.1	SAMN11943029	BIOML-A29	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422965.1	SAMN11943027	BIOML-A27	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422985.1	SAMN11943026	BIOML-A26	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008422995.1	SAMN11943028	BIOML-A28	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423015.1	SAMN11943024	BIOML-A24	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423035.1	SAMN11943025	BIOML-A25	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423065.1	SAMN11943023	BIOML-A23	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423085.1	SAMN11943021	BIOML-A21	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423095.1	SAMN11943022	BIOML-A22	2016-05-12	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423115.1	SAMN11943020	BIOML-A20	2016-01-11	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423135.1	SAMN11943019	BIOML-A19	2016-01-11	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423175.1	SAMN11943018	BIOML-A18	2016-01-11	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423185.1	SAMN11943016	BIOML-A16	2016-01-11	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423215.1	SAMN11943015	BIOML-A15	2016-01-11	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423245.1	SAMN11943014	BIOML-A14	2016-01-11	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423265.1	SAMN11943013	BIOML-A13	2016-01-11	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423275.1	SAMN11943011	BIOML-A11	2016-01-11	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423295.1	SAMN11943009	BIOML-A9	2016-01-11	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423325.1	SAMN11943008	BIOML-A8	2016-01-11	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423335.1	SAMN11943007	BIOML-A7	2016-01-11	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423365.1	SAMN11943006	BIOML-A6	2014-12-18	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423375.1	SAMN11943004	BIOML-A4	2014-12-18	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423385.1	SAMN11943003	BIOML-A3	2014-12-18	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423405.1	SAMN11943005	BIOML-A5	2014-12-18	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423445.1	SAMN11943002	BIOML-A2	2014-12-18	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_008423455.1	SAMN11943001	BIOML-A1	2014-12-18	bodily fluid material biome [ENVO:02000019]	excreta material [ENVO:02000022]	fecal material [ENVO:00002003]	USA:Boston	Homo sapiens	missing	42.36 N 71.06 W	missing	missing	fecal material
#
# GCF_009663785.1	SAMN10240011	D10-15	2016-06-28	intestine enviorment	intestine	animal manure	China:Beijing	ob/ob mouse	mGAM medium at 37 centigrade	39.59 N 116.23 E	1	no applicable
#
# GCF_009731575.1	SAMD00192834	Akkermansia_muciniphila_JCM30893	AKMU	JCM 30893	missing	missing	missing	missing	missing	missing	A_muchiniphila_JCM30893	missing	missing	missing	Homo sapiens
#
# GCF_016697425.1	SAMN16911570	YL44	2019-09	mice microbiota	feces	mice gut	France:Paris	Mus musculus	29051233	not applicable	1	OMM12
#
# GCF_017504145.1	SAMN00138213	ATCC BAA-835
#
# GCF_017566105.1	SAMN14738317	GGCC_0220	feces	Homo sapiens	2019-02	USA: North Carolina	stool sample
#
# GCF_017570425.1	SAMN18309827	KGMB02009	2017-05-18	human	gut	feces	South Korea:Gyeonggi-do, Seongnam-si	Homo sapiens	TSA supplemented with blood	37.35 N 127.15 E	1	10.1099/ijs.0.02873-4
#
# GCF_017570485.1	SAMN18309825	KGMB01989	2017-05-18	human	gut	feces	South Korea:Gyeonggi-do, Seongnam-si	Homo sapiens	TSA supplemented with blood	37.35 N 127.13 E	1	10.1099/ijs.0.02873-2
#
# GCF_017570505.1	SAMN18309826	KGMB01990	2017-05-18	human	gut	feces	South Korea:Gyeonggi-do, Seongnam-si	Homo sapiens	TSA supplemented with blood	37.35 N 127.14 E	1	10.1099/ijs.0.02873-3
#
# GCF_017570525.1	SAMN18309824	KGMB01988	2017-05-18	human	gut	feces	South Korea:Gyeonggi-do, Seongnam-si	Homo sapiens	TSA supplemented with blood	37.35 N 127.12 E	1	10.1099/ijs.0.02873-1
#
# GCF_900184845.1	SAMEA104102601	2017-07-28	2017-05-29	ERC000011	SAMEA104102601	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	2017-07-28T17:03:29Z	2017-05-29T10:55:56Z	public	Chimpanzee_1.fasta	Akkermansia muciniphila	Chimpanzee_1.fasta
#
# GCF_900184905.1	SAMEA104102612	2017-07-28	2017-05-29	ERC000011	SAMEA104102612	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	2017-07-28T17:03:29Z	2017-05-29T10:55:57Z	public	Siamang.fasta	Akkermansia muciniphila	Siamang.fasta
#
# GCF_900184985.1	SAMEA104102607	2017-07-28	2017-05-29	ERC000011	SAMEA104102607	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	2017-07-28T17:03:29Z	2017-05-29T10:55:56Z	public	Mouse_1_89.fasta	Akkermansia muciniphila	Mouse_1_89.fasta
#
# GCF_900185025.1	SAMEA104102606	2017-07-28	2017-05-29	ERC000011	SAMEA104102606	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	2017-07-28T17:03:29Z	2017-05-29T10:55:56Z	public	MG2_JASPER.fasta	Akkermansia muciniphila	MG2_JASPER.fasta
#
# GCF_001683795.1	SAMN03840437	Pyt	reticulated python	feces	2011-10-05	Netherlands: Burgers Zoo, Arnhem	faeces	52.01 N 5.90 E	type strain of Akkermansia glycaniphila
#
# GCF_900097105.1	SAMEA4378782	2016-09-02	2016-08-17	ERC000011	SAMEA4378782	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	2016-09-02T17:03:18Z	2016-08-17T06:39:26Z	public	APytT	APytT
#
# GCF_900184965.1	SAMEA104102608	2017-07-28	2017-05-29	ERC000011	SAMEA104102608	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	2017-07-28T17:03:29Z	2017-05-29T10:55:56Z	public	Mouse_2_MG.fasta	Akkermansia muciniphila	Mouse_2_MG.fasta

# %%
# concatenate both strings
ln = {int(el.split(':')[0]) for el in (ln_sp + ln_comm_sp).strip().split('\n')}
ln_notpresent = [el for el in range(1,181) if el not in ln]
print(ln_notpresent, len(ln_notpresent))
# for el in line_biome_all.split('\n'):
# Out:
# [7, 34, 35, 77, 78, 79, 80, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 168, 174, 176, 177, 179, 180] 34

# %%
for ln in ln_notpresent:
    print(biosample_akk_desc[ln-1])
# Out:
# GCA_003514565.1	SAMN08019340	UBA8862	metagenome	not applicable	not applicable	metagenomic assembly	CLC de novo assembler	4.4.1	BWA (BWA-MEM)	0.7.12-r1039	27.77x	CheckM	1.0.6	97.96%	0.00%	metagenome	true	true	metagenome	This BioSample is a metagenomic assembly obtained from the metagenome reads: SRR606249.
#
# GCF_000020225.1	SAMN00138213	ATCC BAA-835
#
# GCF_000723745.2	SAMEA3139045	GCA_000723745	European Nucleotide Archive	ERC000011	EBI	European Bioinformatics Institute	2014-11-20T12:20:15Z	2014-11-20T11:56:31Z	public	ERS610980	ERS610980	BioSample entry for genome collection GCA_000723745	Urmite
#
# GCF_003716915.1	SAMN07978491	EB-AMDK-1	Korean adult feces	2017-07-20	South Korea: Seoul	cell culture
#
# GCF_003716935.1	SAMN07980909	EB-AMDK-3	Korean adult feces	2017-07-20	South Korea: Seoul	cell culture
#
# GCF_003716955.1	SAMN07980958	EB-AMDK-4	Korean adult feces	2017-07-20	South Korea: Seoul	cell culture
#
# GCF_003716975.1	SAMN07980963	EB-AMDK-2	Korean adult feces	2017-07-20	South Korea: Seoul	cell culture
#
# GCF_010223015.1	SAMN08563913	EB-AMDK-27	Korean adult feces	2018-02-02	South Korea: Seoul	cell culture
#
# GCF_010223075.1	SAMN08563914	EB-AMDK-28	Korean adult feces	2018-02-02	South Korea: Seoul	cell culture
#
# GCF_010223095.1	SAMN08565495	EB-AMDK-29	Korean adult feces	2018-02-02	South Korea: Seoul	cell culture
#
# GCF_010223115.1	SAMN08565496	EB-AMDK-30	Korean adult feces	2018-02-02	South Korea: Seoul	cell culture
#
# GCF_010223135.1	SAMN08565497	EB-AMDK-31	Korean adult feces	2018-02-02	South Korea: Seoul	cell culture
#
# GCF_010223155.1	SAMN08565498	Korean adult feces	2018-02-02	South Korea: Seoul	cell culture	EB-AMDK-33
#
# GCF_010223175.1	SAMN08565499	EB-AMDK-34	Korean adult feces	2018-02-02	South Korea: Seoul	cell culture
#
# GCF_010223195.1	SAMN08565501	EB-AMDK-36	Korean adult feces	2018-02-02	South Korea: Seoul	cell culture
#
# GCF_010223255.1	SAMN08565500	EB-AMDK-35	Korean adult feces	2018-02-02	South Korea: Seoul	cell culture
#
# GCF_010223405.1	SAMN08565502	EB-AMDK-37	Korean adult feces	2018-02-02	South Korea: Seoul	cell culture
#
# GCF_010223575.1	SAMN08565503	EB-AMDK-38	Korean adult feces	2018-02-02	South Korea: Seoul	cell culture
#
# GCF_010229055.1	SAMN09287185	EB-AMDK-5	Korean adult feces	2018-02-08	South Korea: Ilsan	cell culture
#
# GCF_010229495.1	SAMN09287631	EB-AMDK-23	Korean adult feces	2018-02-08	South Korea: Ilsan	cell culture
#
# GCF_010229695.1	SAMN09287781	EB-AMDK-24	Korean adult feces	2018-02-08	South Korea: Ilsan	cell culture
#
# GCF_010229955.1	SAMN09287782	EB-AMDK-25	Korean adult feces	2018-02-08	South Korea: Ilsan	cell culture
#
# GCF_010230155.1	SAMN09287783	EB-AMDK-26	Korean adult feces	2018-02-08	South Korea: Ilsan	cell culture
#
# GCF_010230375.1	SAMN09287787	EB-AMDK-40	Korean adult feces	2018-02-08	South Korea: Ilsan	cell culture
#
# GCF_010230515.1	SAMN09288166	EB-AMDK-46	Korean adult feces	2018-02-08	South Korea: Ilsan	cell culture
#
# GCF_010230725.1	SAMN09288168	EB-AMDK-47	Korean adult feces	2018-02-08	South Korea: Ilsan	cell culture
#
# GCF_010230935.1	SAMN09288183	EB-AMDK-48	Korean adult feces	2018-02-08	South Korea: Ilsan	cell culture
#
# GCF_010231195.1	SAMN09288185	EB-AMDK-49	Korean adult feces	2018-02-08	South Korea: Ilsan	cell culture
#
# GCF_017504145.1	SAMN00138213	ATCC BAA-835
#
# GCF_900184845.1	SAMEA104102601	2017-07-28	2017-05-29	ERC000011	SAMEA104102601	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	2017-07-28T17:03:29Z	2017-05-29T10:55:56Z	public	Chimpanzee_1.fasta	Akkermansia muciniphila	Chimpanzee_1.fasta
#
# GCF_900184985.1	SAMEA104102607	2017-07-28	2017-05-29	ERC000011	SAMEA104102607	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	2017-07-28T17:03:29Z	2017-05-29T10:55:56Z	public	Mouse_1_89.fasta	Akkermansia muciniphila	Mouse_1_89.fasta
#
# GCF_900185025.1	SAMEA104102606	2017-07-28	2017-05-29	ERC000011	SAMEA104102606	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	2017-07-28T17:03:29Z	2017-05-29T10:55:56Z	public	MG2_JASPER.fasta	Akkermansia muciniphila	MG2_JASPER.fasta
#
# GCF_900097105.1	SAMEA4378782	2016-09-02	2016-08-17	ERC000011	SAMEA4378782	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	2016-09-02T17:03:18Z	2016-08-17T06:39:26Z	public	APytT	APytT
#
# GCF_900184965.1	SAMEA104102608	2017-07-28	2017-05-29	ERC000011	SAMEA104102608	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	WAGENINGEN UNIVERSITY, LABORATORY OF SYSTEMS AND SYNTHETIC BIOLOGY.	2017-07-28T17:03:29Z	2017-05-29T10:55:56Z	public	Mouse_2_MG.fasta	Akkermansia muciniphila	Mouse_2_MG.fasta

# %% [markdown]
# # The same, but for BioProject

# %% [markdown]
# ## Read the manually edited file and check BioProjects

# %%
merged_akk = pd.read_csv(qc_path.joinpath('merged_akk_hand_edited.csv'), sep='\t')
merged_akk.info()
merged_akk['host'].value_counts(), merged_df['host'].isna().sum(), merged_akk['type_of_sample'].isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Genome                       201 non-null    object
#  1   Completeness                 201 non-null    float64
#  2   Contamination                201 non-null    float64
#  3   classification               201 non-null    object
#  4   classification_method        201 non-null    object
#  5   sum_len                      201 non-null    int64
#  6   N50                          201 non-null    int64
#  7   16S ribosomal RNA > 1400 nt  151 non-null    float64
#  8   Total_tRNAs                  201 non-null    int64
#  9   host                         179 non-null    object
#  10  NCBI_organism_name           147 non-null    object
#  11  NCBI_infraspecific_name      140 non-null    object
#  12  relation_to_type_material    4 non-null      object
#  13  type_of_sample               194 non-null    object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 22.1+ KB
# (homo sapiens           155
#  mus musculus            13
#  rat                      3
#  gallus gallus            2
#  reticulated python       1
#  horse                    1
#  diceros bicornis         1
#  siamang                  1
#  bufo bufo                1
#  choloepus hoffmanni      1
#  Name: host, dtype: int64,
#  431,
#  7)

# %% [markdown]
# # Set `type_of_sample`

# %%
ln_culture_bp =  build_line_source('bioproject_descr_akk.tsv', "'culture|cultured|isolate|isolated|metagenome|monoisolate|uncultured'", 
                                file_pattern=False)
print(ln_culture_bp[:100])
acc_culture_bp = build_acc_host(ln_culture_bp, 'biosample_descr_akk.tsv')
print(set(acc_culture_bp.values()))
# Out:
# rg -woni 'culture|cultured|isolate|isolated|metagenome|monoisolate|uncultured' bioproject_descr_akk.tsv | sort -h | uniq
# 4:metagenome
# 8:metagenome
# 9:metagenome
# 10:metagenome
# 12:metagenome
# 13:metagenome
# 14:metagenome
# 15:me
# 27
# index for the list in python: 33
# {'uncultured', 'metagenome'}

# %% [markdown]
# **Which bioprojects line numbers aren't present in the `ln_culture`?**

# %%
bp_notin_ln_cult = [int(n.split(':')[0]) for n in ln_culture_bp.strip().split('\n') 
                if n not in ln_culture.strip().split('\n')]
print(len(bp_notin_ln_cult))
for ln in bp_notin_ln_cult:
    print(bioproj_akk_desc[ln-1])
# Out:
# 30
# PRJNA562766	Human gut metagenome	Fecal microbiome analysis of patients with chronic obstructive pulmonary disease	Study analysed metagenomes derived from fecal samples from 28 individuals with chronic obstructive pulmonary disease (COPD) and 29 healthy controls. Paired metabolomic data was also generated for the same samples.
#
# PRJEB26432	Uncultured human gut species	A new genomic blueprint of the human gut microbiota	The composition of the human gut microbiota is linked to health and disease, but knowledge of individual microbial species is needed to decipher their biological roles. Despite extensive culturing and sequencing efforts, the complete bacterial repertoire of the human gut microbiota remains undefined. Here we identify 1,952 uncultured candidate bacterial species by reconstructing 92,143 metagenome-assembled genomes from 11,850 human gut microbiomes. These uncultured genomes substantially expand the known species repertoire of the collective human gut microbiota, with a 281% increase in phylogenetic diversity. Although the newly identified species are less prevalent in well-studied populations compared to reference isolate genomes, they improve classification of understudied African and South American samples by more than 200%. These candidate species encode hundreds of newly identified biosynthetic gene clusters and possess a distinctive functional capacity that might explain their elusive nature. Our work expands the known diversity of uncultured gut bacteria, which provides unprecedented resolution for taxonomic and functional characterization of the intestinal microbiota.
#
# PRJEB26432	Uncultured human gut species	A new genomic blueprint of the human gut microbiota	The composition of the human gut microbiota is linked to health and disease, but knowledge of individual microbial species is needed to decipher their biological roles. Despite extensive culturing and sequencing efforts, the complete bacterial repertoire of the human gut microbiota remains undefined. Here we identify 1,952 uncultured candidate bacterial species by reconstructing 92,143 metagenome-assembled genomes from 11,850 human gut microbiomes. These uncultured genomes substantially expand the known species repertoire of the collective human gut microbiota, with a 281% increase in phylogenetic diversity. Although the newly identified species are less prevalent in well-studied populations compared to reference isolate genomes, they improve classification of understudied African and South American samples by more than 200%. These candidate species encode hundreds of newly identified biosynthetic gene clusters and possess a distinctive functional capacity that might explain their elusive nature. Our work expands the known diversity of uncultured gut bacteria, which provides unprecedented resolution for taxonomic and functional characterization of the intestinal microbiota.
#
# PRJEB26432	Uncultured human gut species	A new genomic blueprint of the human gut microbiota	The composition of the human gut microbiota is linked to health and disease, but knowledge of individual microbial species is needed to decipher their biological roles. Despite extensive culturing and sequencing efforts, the complete bacterial repertoire of the human gut microbiota remains undefined. Here we identify 1,952 uncultured candidate bacterial species by reconstructing 92,143 metagenome-assembled genomes from 11,850 human gut microbiomes. These uncultured genomes substantially expand the known species repertoire of the collective human gut microbiota, with a 281% increase in phylogenetic diversity. Although the newly identified species are less prevalent in well-studied populations compared to reference isolate genomes, they improve classification of understudied African and South American samples by more than 200%. These candidate species encode hundreds of newly identified biosynthetic gene clusters and possess a distinctive functional capacity that might explain their elusive nature. Our work expands the known diversity of uncultured gut bacteria, which provides unprecedented resolution for taxonomic and functional characterization of the intestinal microbiota.
#
# PRJEB26432	Uncultured human gut species	A new genomic blueprint of the human gut microbiota	The composition of the human gut microbiota is linked to health and disease, but knowledge of individual microbial species is needed to decipher their biological roles. Despite extensive culturing and sequencing efforts, the complete bacterial repertoire of the human gut microbiota remains undefined. Here we identify 1,952 uncultured candidate bacterial species by reconstructing 92,143 metagenome-assembled genomes from 11,850 human gut microbiomes. These uncultured genomes substantially expand the known species repertoire of the collective human gut microbiota, with a 281% increase in phylogenetic diversity. Although the newly identified species are less prevalent in well-studied populations compared to reference isolate genomes, they improve classification of understudied African and South American samples by more than 200%. These candidate species encode hundreds of newly identified biosynthetic gene clusters and possess a distinctive functional capacity that might explain their elusive nature. Our work expands the known diversity of uncultured gut bacteria, which provides unprecedented resolution for taxonomic and functional characterization of the intestinal microbiota.
#
# PRJEB26432	Uncultured human gut species	A new genomic blueprint of the human gut microbiota	The composition of the human gut microbiota is linked to health and disease, but knowledge of individual microbial species is needed to decipher their biological roles. Despite extensive culturing and sequencing efforts, the complete bacterial repertoire of the human gut microbiota remains undefined. Here we identify 1,952 uncultured candidate bacterial species by reconstructing 92,143 metagenome-assembled genomes from 11,850 human gut microbiomes. These uncultured genomes substantially expand the known species repertoire of the collective human gut microbiota, with a 281% increase in phylogenetic diversity. Although the newly identified species are less prevalent in well-studied populations compared to reference isolate genomes, they improve classification of understudied African and South American samples by more than 200%. These candidate species encode hundreds of newly identified biosynthetic gene clusters and possess a distinctive functional capacity that might explain their elusive nature. Our work expands the known diversity of uncultured gut bacteria, which provides unprecedented resolution for taxonomic and functional characterization of the intestinal microbiota.
#
# PRJEB26432	Uncultured human gut species	A new genomic blueprint of the human gut microbiota	The composition of the human gut microbiota is linked to health and disease, but knowledge of individual microbial species is needed to decipher their biological roles. Despite extensive culturing and sequencing efforts, the complete bacterial repertoire of the human gut microbiota remains undefined. Here we identify 1,952 uncultured candidate bacterial species by reconstructing 92,143 metagenome-assembled genomes from 11,850 human gut microbiomes. These uncultured genomes substantially expand the known species repertoire of the collective human gut microbiota, with a 281% increase in phylogenetic diversity. Although the newly identified species are less prevalent in well-studied populations compared to reference isolate genomes, they improve classification of understudied African and South American samples by more than 200%. These candidate species encode hundreds of newly identified biosynthetic gene clusters and possess a distinctive functional capacity that might explain their elusive nature. Our work expands the known diversity of uncultured gut bacteria, which provides unprecedented resolution for taxonomic and functional characterization of the intestinal microbiota.
#
# PRJEB26432	Uncultured human gut species	A new genomic blueprint of the human gut microbiota	The composition of the human gut microbiota is linked to health and disease, but knowledge of individual microbial species is needed to decipher their biological roles. Despite extensive culturing and sequencing efforts, the complete bacterial repertoire of the human gut microbiota remains undefined. Here we identify 1,952 uncultured candidate bacterial species by reconstructing 92,143 metagenome-assembled genomes from 11,850 human gut microbiomes. These uncultured genomes substantially expand the known species repertoire of the collective human gut microbiota, with a 281% increase in phylogenetic diversity. Although the newly identified species are less prevalent in well-studied populations compared to reference isolate genomes, they improve classification of understudied African and South American samples by more than 200%. These candidate species encode hundreds of newly identified biosynthetic gene clusters and possess a distinctive functional capacity that might explain their elusive nature. Our work expands the known diversity of uncultured gut bacteria, which provides unprecedented resolution for taxonomic and functional characterization of the intestinal microbiota.
#
# PRJEB26432	Uncultured human gut species	A new genomic blueprint of the human gut microbiota	The composition of the human gut microbiota is linked to health and disease, but knowledge of individual microbial species is needed to decipher their biological roles. Despite extensive culturing and sequencing efforts, the complete bacterial repertoire of the human gut microbiota remains undefined. Here we identify 1,952 uncultured candidate bacterial species by reconstructing 92,143 metagenome-assembled genomes from 11,850 human gut microbiomes. These uncultured genomes substantially expand the known species repertoire of the collective human gut microbiota, with a 281% increase in phylogenetic diversity. Although the newly identified species are less prevalent in well-studied populations compared to reference isolate genomes, they improve classification of understudied African and South American samples by more than 200%. These candidate species encode hundreds of newly identified biosynthetic gene clusters and possess a distinctive functional capacity that might explain their elusive nature. Our work expands the known diversity of uncultured gut bacteria, which provides unprecedented resolution for taxonomic and functional characterization of the intestinal microbiota.
#
# PRJEB26432	Uncultured human gut species	A new genomic blueprint of the human gut microbiota	The composition of the human gut microbiota is linked to health and disease, but knowledge of individual microbial species is needed to decipher their biological roles. Despite extensive culturing and sequencing efforts, the complete bacterial repertoire of the human gut microbiota remains undefined. Here we identify 1,952 uncultured candidate bacterial species by reconstructing 92,143 metagenome-assembled genomes from 11,850 human gut microbiomes. These uncultured genomes substantially expand the known species repertoire of the collective human gut microbiota, with a 281% increase in phylogenetic diversity. Although the newly identified species are less prevalent in well-studied populations compared to reference isolate genomes, they improve classification of understudied African and South American samples by more than 200%. These candidate species encode hundreds of newly identified biosynthetic gene clusters and possess a distinctive functional capacity that might explain their elusive nature. Our work expands the known diversity of uncultured gut bacteria, which provides unprecedented resolution for taxonomic and functional characterization of the intestinal microbiota.
#
# PRJEB31003	Global Human Gut MAG (HGM) Dataset	Prokaryotic genomes for 2058 new species assembled from globally distributed human gut metagenomes	Largely due to challenges cultivating microbes under laboratory conditions, many species in the human gut microbiome do not have a genome sequence. To address this problem, we reconstructed 60,664 prokaryotic draft genomes from 3,810 fecal metagenomes from geographically and phenotypically diverse human subjects. These genomes provide reference points for 2,058 previously unknown uncultured species and nearly double the phylogenetic diversity of sequenced gut Bacteria. New species comprise 33% of species richness and 28% of species abundance per individual on average and are more common in humans living rural lifestyles. A metagenome-wide association study of ten human diseases revealed thousands of new species-level biomarkers, particularly for colorectal cancer, ankylosing spondylitis, and obesity. Our analysis also uncovered novel genomic and ecological features of uncultured species, including reduced genome size, metabolic auxotrophies, and increased richness in high-diversity communities. We anticipate that this dataset and associated tools will drive new culturing efforts and enable further discoveries from the human gut microbiome.
#
# PRJEB31003	Global Human Gut MAG (HGM) Dataset	Prokaryotic genomes for 2058 new species assembled from globally distributed human gut metagenomes	Largely due to challenges cultivating microbes under laboratory conditions, many species in the human gut microbiome do not have a genome sequence. To address this problem, we reconstructed 60,664 prokaryotic draft genomes from 3,810 fecal metagenomes from geographically and phenotypically diverse human subjects. These genomes provide reference points for 2,058 previously unknown uncultured species and nearly double the phylogenetic diversity of sequenced gut Bacteria. New species comprise 33% of species richness and 28% of species abundance per individual on average and are more common in humans living rural lifestyles. A metagenome-wide association study of ten human diseases revealed thousands of new species-level biomarkers, particularly for colorectal cancer, ankylosing spondylitis, and obesity. Our analysis also uncovered novel genomic and ecological features of uncultured species, including reduced genome size, metabolic auxotrophies, and increased richness in high-diversity communities. We anticipate that this dataset and associated tools will drive new culturing efforts and enable further discoveries from the human gut microbiome.
#
# PRJEB31003	Global Human Gut MAG (HGM) Dataset	Prokaryotic genomes for 2058 new species assembled from globally distributed human gut metagenomes	Largely due to challenges cultivating microbes under laboratory conditions, many species in the human gut microbiome do not have a genome sequence. To address this problem, we reconstructed 60,664 prokaryotic draft genomes from 3,810 fecal metagenomes from geographically and phenotypically diverse human subjects. These genomes provide reference points for 2,058 previously unknown uncultured species and nearly double the phylogenetic diversity of sequenced gut Bacteria. New species comprise 33% of species richness and 28% of species abundance per individual on average and are more common in humans living rural lifestyles. A metagenome-wide association study of ten human diseases revealed thousands of new species-level biomarkers, particularly for colorectal cancer, ankylosing spondylitis, and obesity. Our analysis also uncovered novel genomic and ecological features of uncultured species, including reduced genome size, metabolic auxotrophies, and increased richness in high-diversity communities. We anticipate that this dataset and associated tools will drive new culturing efforts and enable further discoveries from the human gut microbiome.
#
# PRJEB37358	Uncultured novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Recovery of novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Metabolic diseases such as type 2 diabetes (T2D) and T2D-related comorbidities (eg. obesity, metabolic syndrome, pre-diabetes and impaired glucose tolerance) are major public health issues worldwide. Recent experiments in animal and human studies have generated growing evidence for the association of gut microbiome and development of these diseases. Using next generation sequencing, large amounts of metagenomic data have been generated from T2D and control subjects. However, the disease-associated prokaryotic repertoire of the human gut microbiota is still undefined. Here we identified 389 uncultured novel prokaryotic species, including 388 bacteria and 1 archaea, by reconstructing 95871 metagenome-assembled genomes (MAGs) from 5814 disease-associated human gut microbiomes and de-replicating the MAGs against a comprehensive human gut library (ERP108418). Amongst these uncultured genomes, 302 are novel species and 87 are related to known species but have never been found in the human gut before. Our work expands the knowledge of the diversity of uncultured human gut bacteria associated with metabolic diseases, and can be used as a valuable reference library to help improve the species detection in future disease-associated metagenomics studies.
#
# PRJEB37358	Uncultured novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Recovery of novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Metabolic diseases such as type 2 diabetes (T2D) and T2D-related comorbidities (eg. obesity, metabolic syndrome, pre-diabetes and impaired glucose tolerance) are major public health issues worldwide. Recent experiments in animal and human studies have generated growing evidence for the association of gut microbiome and development of these diseases. Using next generation sequencing, large amounts of metagenomic data have been generated from T2D and control subjects. However, the disease-associated prokaryotic repertoire of the human gut microbiota is still undefined. Here we identified 389 uncultured novel prokaryotic species, including 388 bacteria and 1 archaea, by reconstructing 95871 metagenome-assembled genomes (MAGs) from 5814 disease-associated human gut microbiomes and de-replicating the MAGs against a comprehensive human gut library (ERP108418). Amongst these uncultured genomes, 302 are novel species and 87 are related to known species but have never been found in the human gut before. Our work expands the knowledge of the diversity of uncultured human gut bacteria associated with metabolic diseases, and can be used as a valuable reference library to help improve the species detection in future disease-associated metagenomics studies.
#
# PRJEB37358	Uncultured novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Recovery of novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Metabolic diseases such as type 2 diabetes (T2D) and T2D-related comorbidities (eg. obesity, metabolic syndrome, pre-diabetes and impaired glucose tolerance) are major public health issues worldwide. Recent experiments in animal and human studies have generated growing evidence for the association of gut microbiome and development of these diseases. Using next generation sequencing, large amounts of metagenomic data have been generated from T2D and control subjects. However, the disease-associated prokaryotic repertoire of the human gut microbiota is still undefined. Here we identified 389 uncultured novel prokaryotic species, including 388 bacteria and 1 archaea, by reconstructing 95871 metagenome-assembled genomes (MAGs) from 5814 disease-associated human gut microbiomes and de-replicating the MAGs against a comprehensive human gut library (ERP108418). Amongst these uncultured genomes, 302 are novel species and 87 are related to known species but have never been found in the human gut before. Our work expands the knowledge of the diversity of uncultured human gut bacteria associated with metabolic diseases, and can be used as a valuable reference library to help improve the species detection in future disease-associated metagenomics studies.
#
# PRJEB37358	Uncultured novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Recovery of novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Metabolic diseases such as type 2 diabetes (T2D) and T2D-related comorbidities (eg. obesity, metabolic syndrome, pre-diabetes and impaired glucose tolerance) are major public health issues worldwide. Recent experiments in animal and human studies have generated growing evidence for the association of gut microbiome and development of these diseases. Using next generation sequencing, large amounts of metagenomic data have been generated from T2D and control subjects. However, the disease-associated prokaryotic repertoire of the human gut microbiota is still undefined. Here we identified 389 uncultured novel prokaryotic species, including 388 bacteria and 1 archaea, by reconstructing 95871 metagenome-assembled genomes (MAGs) from 5814 disease-associated human gut microbiomes and de-replicating the MAGs against a comprehensive human gut library (ERP108418). Amongst these uncultured genomes, 302 are novel species and 87 are related to known species but have never been found in the human gut before. Our work expands the knowledge of the diversity of uncultured human gut bacteria associated with metabolic diseases, and can be used as a valuable reference library to help improve the species detection in future disease-associated metagenomics studies.
#
# PRJEB37358	Uncultured novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Recovery of novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Metabolic diseases such as type 2 diabetes (T2D) and T2D-related comorbidities (eg. obesity, metabolic syndrome, pre-diabetes and impaired glucose tolerance) are major public health issues worldwide. Recent experiments in animal and human studies have generated growing evidence for the association of gut microbiome and development of these diseases. Using next generation sequencing, large amounts of metagenomic data have been generated from T2D and control subjects. However, the disease-associated prokaryotic repertoire of the human gut microbiota is still undefined. Here we identified 389 uncultured novel prokaryotic species, including 388 bacteria and 1 archaea, by reconstructing 95871 metagenome-assembled genomes (MAGs) from 5814 disease-associated human gut microbiomes and de-replicating the MAGs against a comprehensive human gut library (ERP108418). Amongst these uncultured genomes, 302 are novel species and 87 are related to known species but have never been found in the human gut before. Our work expands the knowledge of the diversity of uncultured human gut bacteria associated with metabolic diseases, and can be used as a valuable reference library to help improve the species detection in future disease-associated metagenomics studies.
#
# PRJEB37358	Uncultured novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Recovery of novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Metabolic diseases such as type 2 diabetes (T2D) and T2D-related comorbidities (eg. obesity, metabolic syndrome, pre-diabetes and impaired glucose tolerance) are major public health issues worldwide. Recent experiments in animal and human studies have generated growing evidence for the association of gut microbiome and development of these diseases. Using next generation sequencing, large amounts of metagenomic data have been generated from T2D and control subjects. However, the disease-associated prokaryotic repertoire of the human gut microbiota is still undefined. Here we identified 389 uncultured novel prokaryotic species, including 388 bacteria and 1 archaea, by reconstructing 95871 metagenome-assembled genomes (MAGs) from 5814 disease-associated human gut microbiomes and de-replicating the MAGs against a comprehensive human gut library (ERP108418). Amongst these uncultured genomes, 302 are novel species and 87 are related to known species but have never been found in the human gut before. Our work expands the knowledge of the diversity of uncultured human gut bacteria associated with metabolic diseases, and can be used as a valuable reference library to help improve the species detection in future disease-associated metagenomics studies.
#
# PRJEB37358	Uncultured novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Recovery of novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Metabolic diseases such as type 2 diabetes (T2D) and T2D-related comorbidities (eg. obesity, metabolic syndrome, pre-diabetes and impaired glucose tolerance) are major public health issues worldwide. Recent experiments in animal and human studies have generated growing evidence for the association of gut microbiome and development of these diseases. Using next generation sequencing, large amounts of metagenomic data have been generated from T2D and control subjects. However, the disease-associated prokaryotic repertoire of the human gut microbiota is still undefined. Here we identified 389 uncultured novel prokaryotic species, including 388 bacteria and 1 archaea, by reconstructing 95871 metagenome-assembled genomes (MAGs) from 5814 disease-associated human gut microbiomes and de-replicating the MAGs against a comprehensive human gut library (ERP108418). Amongst these uncultured genomes, 302 are novel species and 87 are related to known species but have never been found in the human gut before. Our work expands the knowledge of the diversity of uncultured human gut bacteria associated with metabolic diseases, and can be used as a valuable reference library to help improve the species detection in future disease-associated metagenomics studies.
#
# PRJEB37358	Uncultured novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Recovery of novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Metabolic diseases such as type 2 diabetes (T2D) and T2D-related comorbidities (eg. obesity, metabolic syndrome, pre-diabetes and impaired glucose tolerance) are major public health issues worldwide. Recent experiments in animal and human studies have generated growing evidence for the association of gut microbiome and development of these diseases. Using next generation sequencing, large amounts of metagenomic data have been generated from T2D and control subjects. However, the disease-associated prokaryotic repertoire of the human gut microbiota is still undefined. Here we identified 389 uncultured novel prokaryotic species, including 388 bacteria and 1 archaea, by reconstructing 95871 metagenome-assembled genomes (MAGs) from 5814 disease-associated human gut microbiomes and de-replicating the MAGs against a comprehensive human gut library (ERP108418). Amongst these uncultured genomes, 302 are novel species and 87 are related to known species but have never been found in the human gut before. Our work expands the knowledge of the diversity of uncultured human gut bacteria associated with metabolic diseases, and can be used as a valuable reference library to help improve the species detection in future disease-associated metagenomics studies.
#
# PRJEB37358	Uncultured novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Recovery of novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Metabolic diseases such as type 2 diabetes (T2D) and T2D-related comorbidities (eg. obesity, metabolic syndrome, pre-diabetes and impaired glucose tolerance) are major public health issues worldwide. Recent experiments in animal and human studies have generated growing evidence for the association of gut microbiome and development of these diseases. Using next generation sequencing, large amounts of metagenomic data have been generated from T2D and control subjects. However, the disease-associated prokaryotic repertoire of the human gut microbiota is still undefined. Here we identified 389 uncultured novel prokaryotic species, including 388 bacteria and 1 archaea, by reconstructing 95871 metagenome-assembled genomes (MAGs) from 5814 disease-associated human gut microbiomes and de-replicating the MAGs against a comprehensive human gut library (ERP108418). Amongst these uncultured genomes, 302 are novel species and 87 are related to known species but have never been found in the human gut before. Our work expands the knowledge of the diversity of uncultured human gut bacteria associated with metabolic diseases, and can be used as a valuable reference library to help improve the species detection in future disease-associated metagenomics studies.
#
# PRJEB37358	Uncultured novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Recovery of novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Metabolic diseases such as type 2 diabetes (T2D) and T2D-related comorbidities (eg. obesity, metabolic syndrome, pre-diabetes and impaired glucose tolerance) are major public health issues worldwide. Recent experiments in animal and human studies have generated growing evidence for the association of gut microbiome and development of these diseases. Using next generation sequencing, large amounts of metagenomic data have been generated from T2D and control subjects. However, the disease-associated prokaryotic repertoire of the human gut microbiota is still undefined. Here we identified 389 uncultured novel prokaryotic species, including 388 bacteria and 1 archaea, by reconstructing 95871 metagenome-assembled genomes (MAGs) from 5814 disease-associated human gut microbiomes and de-replicating the MAGs against a comprehensive human gut library (ERP108418). Amongst these uncultured genomes, 302 are novel species and 87 are related to known species but have never been found in the human gut before. Our work expands the knowledge of the diversity of uncultured human gut bacteria associated with metabolic diseases, and can be used as a valuable reference library to help improve the species detection in future disease-associated metagenomics studies.
#
# PRJEB37358	Uncultured novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Recovery of novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Metabolic diseases such as type 2 diabetes (T2D) and T2D-related comorbidities (eg. obesity, metabolic syndrome, pre-diabetes and impaired glucose tolerance) are major public health issues worldwide. Recent experiments in animal and human studies have generated growing evidence for the association of gut microbiome and development of these diseases. Using next generation sequencing, large amounts of metagenomic data have been generated from T2D and control subjects. However, the disease-associated prokaryotic repertoire of the human gut microbiota is still undefined. Here we identified 389 uncultured novel prokaryotic species, including 388 bacteria and 1 archaea, by reconstructing 95871 metagenome-assembled genomes (MAGs) from 5814 disease-associated human gut microbiomes and de-replicating the MAGs against a comprehensive human gut library (ERP108418). Amongst these uncultured genomes, 302 are novel species and 87 are related to known species but have never been found in the human gut before. Our work expands the knowledge of the diversity of uncultured human gut bacteria associated with metabolic diseases, and can be used as a valuable reference library to help improve the species detection in future disease-associated metagenomics studies.
#
# PRJEB37358	Uncultured novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Recovery of novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Metabolic diseases such as type 2 diabetes (T2D) and T2D-related comorbidities (eg. obesity, metabolic syndrome, pre-diabetes and impaired glucose tolerance) are major public health issues worldwide. Recent experiments in animal and human studies have generated growing evidence for the association of gut microbiome and development of these diseases. Using next generation sequencing, large amounts of metagenomic data have been generated from T2D and control subjects. However, the disease-associated prokaryotic repertoire of the human gut microbiota is still undefined. Here we identified 389 uncultured novel prokaryotic species, including 388 bacteria and 1 archaea, by reconstructing 95871 metagenome-assembled genomes (MAGs) from 5814 disease-associated human gut microbiomes and de-replicating the MAGs against a comprehensive human gut library (ERP108418). Amongst these uncultured genomes, 302 are novel species and 87 are related to known species but have never been found in the human gut before. Our work expands the knowledge of the diversity of uncultured human gut bacteria associated with metabolic diseases, and can be used as a valuable reference library to help improve the species detection in future disease-associated metagenomics studies.
#
# PRJEB37358	Uncultured novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Recovery of novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Metabolic diseases such as type 2 diabetes (T2D) and T2D-related comorbidities (eg. obesity, metabolic syndrome, pre-diabetes and impaired glucose tolerance) are major public health issues worldwide. Recent experiments in animal and human studies have generated growing evidence for the association of gut microbiome and development of these diseases. Using next generation sequencing, large amounts of metagenomic data have been generated from T2D and control subjects. However, the disease-associated prokaryotic repertoire of the human gut microbiota is still undefined. Here we identified 389 uncultured novel prokaryotic species, including 388 bacteria and 1 archaea, by reconstructing 95871 metagenome-assembled genomes (MAGs) from 5814 disease-associated human gut microbiomes and de-replicating the MAGs against a comprehensive human gut library (ERP108418). Amongst these uncultured genomes, 302 are novel species and 87 are related to known species but have never been found in the human gut before. Our work expands the knowledge of the diversity of uncultured human gut bacteria associated with metabolic diseases, and can be used as a valuable reference library to help improve the species detection in future disease-associated metagenomics studies.
#
# PRJEB37358	Uncultured novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Recovery of novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Metabolic diseases such as type 2 diabetes (T2D) and T2D-related comorbidities (eg. obesity, metabolic syndrome, pre-diabetes and impaired glucose tolerance) are major public health issues worldwide. Recent experiments in animal and human studies have generated growing evidence for the association of gut microbiome and development of these diseases. Using next generation sequencing, large amounts of metagenomic data have been generated from T2D and control subjects. However, the disease-associated prokaryotic repertoire of the human gut microbiota is still undefined. Here we identified 389 uncultured novel prokaryotic species, including 388 bacteria and 1 archaea, by reconstructing 95871 metagenome-assembled genomes (MAGs) from 5814 disease-associated human gut microbiomes and de-replicating the MAGs against a comprehensive human gut library (ERP108418). Amongst these uncultured genomes, 302 are novel species and 87 are related to known species but have never been found in the human gut before. Our work expands the knowledge of the diversity of uncultured human gut bacteria associated with metabolic diseases, and can be used as a valuable reference library to help improve the species detection in future disease-associated metagenomics studies.
#
# PRJEB37358	Uncultured novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Recovery of novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Metabolic diseases such as type 2 diabetes (T2D) and T2D-related comorbidities (eg. obesity, metabolic syndrome, pre-diabetes and impaired glucose tolerance) are major public health issues worldwide. Recent experiments in animal and human studies have generated growing evidence for the association of gut microbiome and development of these diseases. Using next generation sequencing, large amounts of metagenomic data have been generated from T2D and control subjects. However, the disease-associated prokaryotic repertoire of the human gut microbiota is still undefined. Here we identified 389 uncultured novel prokaryotic species, including 388 bacteria and 1 archaea, by reconstructing 95871 metagenome-assembled genomes (MAGs) from 5814 disease-associated human gut microbiomes and de-replicating the MAGs against a comprehensive human gut library (ERP108418). Amongst these uncultured genomes, 302 are novel species and 87 are related to known species but have never been found in the human gut before. Our work expands the knowledge of the diversity of uncultured human gut bacteria associated with metabolic diseases, and can be used as a valuable reference library to help improve the species detection in future disease-associated metagenomics studies.
#
# PRJEB37358	Uncultured novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Recovery of novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Metabolic diseases such as type 2 diabetes (T2D) and T2D-related comorbidities (eg. obesity, metabolic syndrome, pre-diabetes and impaired glucose tolerance) are major public health issues worldwide. Recent experiments in animal and human studies have generated growing evidence for the association of gut microbiome and development of these diseases. Using next generation sequencing, large amounts of metagenomic data have been generated from T2D and control subjects. However, the disease-associated prokaryotic repertoire of the human gut microbiota is still undefined. Here we identified 389 uncultured novel prokaryotic species, including 388 bacteria and 1 archaea, by reconstructing 95871 metagenome-assembled genomes (MAGs) from 5814 disease-associated human gut microbiomes and de-replicating the MAGs against a comprehensive human gut library (ERP108418). Amongst these uncultured genomes, 302 are novel species and 87 are related to known species but have never been found in the human gut before. Our work expands the knowledge of the diversity of uncultured human gut bacteria associated with metabolic diseases, and can be used as a valuable reference library to help improve the species detection in future disease-associated metagenomics studies.
#
# PRJEB37358	Uncultured novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Recovery of novel prokaryotic genomes associated with metabolic diseases such as T2D and T2D-related comorbidities	Metabolic diseases such as type 2 diabetes (T2D) and T2D-related comorbidities (eg. obesity, metabolic syndrome, pre-diabetes and impaired glucose tolerance) are major public health issues worldwide. Recent experiments in animal and human studies have generated growing evidence for the association of gut microbiome and development of these diseases. Using next generation sequencing, large amounts of metagenomic data have been generated from T2D and control subjects. However, the disease-associated prokaryotic repertoire of the human gut microbiota is still undefined. Here we identified 389 uncultured novel prokaryotic species, including 388 bacteria and 1 archaea, by reconstructing 95871 metagenome-assembled genomes (MAGs) from 5814 disease-associated human gut microbiomes and de-replicating the MAGs against a comprehensive human gut library (ERP108418). Amongst these uncultured genomes, 302 are novel species and 87 are related to known species but have never been found in the human gut before. Our work expands the knowledge of the diversity of uncultured human gut bacteria associated with metabolic diseases, and can be used as a valuable reference library to help improve the species detection in future disease-associated metagenomics studies.

# %% [markdown]
# # Make a table with assembly-biosample-bioproject equivalencies
# Then, we can use this mappings to get the assemblies easily

# %%
ncbi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1158218 entries, 0 to 1158217
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Genome                     1158163 non-null  object
#  1   assembly_accession         1158218 non-null  object
#  2   bioproject                 1158214 non-null  object
#  3   biosample                  1158213 non-null  object
#  4   wgs_master                 1104090 non-null  object
#  5   refseq_category            1158218 non-null  object
#  6   taxid                      1158218 non-null  int64
#  7   species_taxid              1158218 non-null  int64
#  8   NCBI_organism_name         1158218 non-null  object
#  9   NCBI_infraspecific_name    998033 non-null   object
#  10  isolate                    182630 non-null   object
#  11  version_status             1158218 non-null  object
#  12  assembly_level             1158218 non-null  object
#  13  release_type               1158218 non-null  object
#  14  genome_rep                 1158218 non-null  object
#  15  seq_rel_date               1158218 non-null  object
#  16  asm_name                   1158217 non-null  object
#  17  submitter                  1158210 non-null  object
#  18  gbrs_paired_asm            1158218 non-null  object
#  19  paired_asm_comp            1158218 non-null  object
#  20  ftp_path                   1158218 non-null  object
#  21  excluded_from_refseq       726985 non-null   object
#  22  relation_to_type_material  32556 non-null    object
# dtypes: int64(2), object(21)
# memory usage: 203.2+ MB

# %%
merged_df.head(2)
# Out:
#                                               Genome  Completeness  \
# 0            DGYMR06203__metabat2_low_PE.047.contigs         91.12
# 1  F157a_European_Toad__metabat2_high_PE.005.contigs         89.32
#
#    Contamination                                     classification  \
# 0            0.0  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 1            2.3  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
#
#                                classification_method  sum_len    N50  \
# 0  taxonomic classification defined by topology a...  2417897  26278
# 1  taxonomic classification defined by topology a...  2029501   8457
#
#    16S ribosomal RNA > 1400 nt  Total_tRNAs           host NCBI_organism_name  \
# 0                          NaN           44  gallus gallus                NaN
# 1                          NaN           40      bufo bufo                NaN
#
#   NCBI_infraspecific_name relation_to_type_material type_of_sample
# 0                     NaN                       NaN            NaN
# 1                     NaN                       NaN            NaN

# %%
all_accs = (merged_df.loc[:,'Genome'].str.extract( '(GC[AF]_[0-9]{9}\.[1-9])').
            dropna().values.flatten())
asm_biosam_bioproj = (ncbi_df.set_index('assembly_accession').loc[all_accs, :].
                      loc[:, ['biosample', 'bioproject']].reset_index())
asm_biosam_bioproj.head(2)
# Out:
#   assembly_accession     biosample  bioproject
# 0    GCA_000155695.1  SAMN02436317  PRJNA19391
# 1    GCA_000242935.3  SAMN02261410  PRJNA63271

# %%
asms = {bioproj_akk_desc[ln-1].split('\t')[0] for ln in bp_notin_ln_cult}
asm_biosam_bioproj.set_index('bioproject').loc[asms, :]
# Out:
#             assembly_accession     biosample
# bioproject
# PRJEB31003     GCA_900752515.1  SAMEA5279134
# PRJEB31003     GCA_900759685.1  SAMEA5279138
# PRJEB31003     GCA_900760665.1  SAMEA5279772
# PRJEB31003     GCA_900763545.1  SAMEA5279771
# PRJEB31003     GCA_900765745.1  SAMEA5279136
# PRJEB37358     GCA_905193115.1  SAMEA7846742
# PRJEB37358     GCA_905193715.1  SAMEA7847250
# PRJEB37358     GCA_905197035.1  SAMEA7847110
# PRJEB37358     GCA_905198945.1  SAMEA7846640
# PRJEB37358     GCA_905200125.1  SAMEA7848347
# PRJEB37358     GCA_905200945.1  SAMEA7847584
# PRJEB37358     GCA_905205055.1  SAMEA7848078
# PRJEB37358     GCA_905205865.1  SAMEA7846715
# PRJEB37358     GCA_905205915.1  SAMEA7846587
# PRJEB37358     GCA_905210405.1  SAMEA7847399
# PRJEB37358     GCA_905210615.1  SAMEA7847488
# PRJNA562766    GCA_014871965.1  SAMN12905381
# PRJNA562766    GCA_014871995.1  SAMN12905379
# PRJNA562766    GCA_014872005.1  SAMN12905380
# PRJNA562766    GCA_014872035.1  SAMN12905378
# PRJNA562766    GCA_014872065.1  SAMN12905377
# PRJNA562766    GCA_014872075.1  SAMN12905375
# PRJNA562766    GCA_014872105.1  SAMN12905376
# PRJNA562766    GCA_014872125.1  SAMN12905373
# PRJNA562766    GCA_014872165.1  SAMN12905372
# PRJEB26432     GCA_900539575.1  SAMEA4890833
# PRJEB26432     GCA_900539895.1  SAMEA4890871
# PRJEB26432     GCA_900545155.1  SAMEA4891402
# PRJEB26432     GCA_900547395.1  SAMEA4891626

# %%
idxs = set(merged_akk[merged_akk['type_of_sample'].isna()]['Genome'].str.
 extract( '(GC[AF]_[0-9]{9}\.[1-9])').dropna().values.flatten()) 

asm_biosam_bioproj.set_index('assembly_accession').loc[idxs, :]#.str.extract( '(GC[AF]_[0-9]{9}\.[1-9])').dropna().values.flatten()
# Out:
#                        biosample   bioproject
# assembly_accession
# GCF_009731575.1     SAMD00192834  PRJNA224116
# GCF_001688765.2     SAMN04621615  PRJNA224116
# GCF_002161325.1     SAMN06473757  PRJNA224116
# GCF_002201495.1     SAMN03854119  PRJNA224116
# GCF_009663785.1     SAMN10240011  PRJNA224116
# GCF_001647615.1     SAMN04606485  PRJNA224116
# GCF_000723745.2     SAMEA3139045  PRJNA224116

# %%
ls = asm_biosam_bioproj.set_index('assembly_accession').loc[idxs, :].loc[:,'biosample'].to_list()
for bp in ls:
    print(bp)
    ! esearch -db biosample -query $bp | efetch -format xml | xtract -pattern BioSampleSet -element  Title  Attribute  OrganismName
# Out:
# SAMD00192834
# AMJCM30893	Akkermansia_muciniphila_JCM30893	AKMU	JCM 30893	missing	missing	missing	missing	missing	missing	A_muchiniphila_JCM30893	missing	missing	missing	Homo sapiens	Akkermansia muciniphila
# SAMN04621615
# Microbe sample from Akkermansia muciniphila	YL44	Mus musculus	2015-02-26	Switzerland: Bern	whole organism	Akkermansia muciniphila
# SAMN06473757
# MIGS Cultured Bacterial/Archaeal sample from Akkermansia muciniphila	healthy	missing	not applicable	missing	not applicable	Gallus gallus	not applicable	not applicable	commensal	caecum	An78	anaerobe	caecum	2016	not applicable	missing	Akkermansia muciniphila
# SAMN03854119
# Akkermansia muciniphila YL44	YL44	Switzerland: Zurich	not applicable	not applicable	not applicable	organic feature	intestine environment	47 N 8 E	organic material	not applicable	Mus musculus	DSM:26127	Akkermansia muciniphila
# SAMN10240011
# MIGS Cultured Bacterial/Archaeal sample from Akkermansia muciniphila	D10-15	2016-06-28	intestine enviorment	intestine	animal manure	China:Beijing	ob/ob mouse	mGAM medium at 37 centigrade	39.59 N 116.23 E	1	no applicable	Akkermansia muciniphila
# SAMN04606485
# Sample from Akkermansia sp. KLE1605	GI tract	KLE1605	Homo sapiens	High-Quality Draft	High-Quality Draft	Velvet v. 1.1.04	128x	Illumina	Akkermansia sp. KLE1605
# SAMEA3139045
# GCA_000723745	GCA_000723745	European Nucleotide Archive	ERC000011	EBI	European Bioinformatics Institute	2014-11-20T12:20:15Z	2014-11-20T11:56:31Z	public	ERS610980	ERS610980	BioSample entry for genome collection GCA_000723745	Urmite	Akkermansia muciniphila

# %% [markdown]
# # Annotation for the non-akkermansia assemblies

# %%
merged_non_akk = merged_df[~merged_df['classification'].str.contains('g__Akkermansia')].copy()
(merged_non_akk['host'].value_counts(), 
 merged_non_akk['type_of_sample'].value_counts(), merged_non_akk['type_of_sample'].isna().sum())
# Out:
# (Series([], Name: host, dtype: int64),
#  Series([], Name: type_of_sample, dtype: int64),
#  384)

# %%
merged_non_akk.head(3)
# Out:
#                                Genome  Completeness  Contamination  \
# 2  GCA_000155695.1_ASM15569v1_genomic        100.00           1.35
# 3  GCA_000242935.3_ASM24293v3_genomic        100.00           0.23
# 4  GCA_000243495.3_ASM24349v3_genomic         98.63           0.23
#
#                                       classification  \
# 2  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 3  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 4  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
#
#                                classification_method  sum_len      N50  \
# 2  taxonomic classification defined by topology a...  5775745  5514226
# 3  taxonomic classification defined by topology a...  7417673  7317842
# 4  taxonomic classification defined by topology a...  7073483  6196881
#
#    16S ribosomal RNA > 1400 nt  Total_tRNAs host NCBI_organism_name  \
# 2                          1.0           45  NaN                NaN
# 3                          1.0           52  NaN                NaN
# 4                          1.0           71  NaN                NaN
#
#   NCBI_infraspecific_name relation_to_type_material type_of_sample
# 2                     NaN                       NaN            NaN
# 3                     NaN                       NaN            NaN
# 4                     NaN                       NaN            NaN

# %%
ln_comm_sp =  build_line_source('biosample_descr_non_akk.tsv', common_pats, file_pattern=True)
ln_sp =  build_line_source('biosample_descr_non_akk.tsv', sp_pats, file_pattern=True)
acc_comm_sp = build_acc_host(ln_comm_sp, 'biosample_descr_non_akk.tsv')
acc_sp = build_acc_host(ln_sp, 'biosample_descr_non_akk.tsv')
add_info_to_summary(merged_non_akk, 'host', acc_comm_sp, acc_sp)
# Out:
# rg -woni -f /home/mibu/common_names_ncbi.list biosample_descr_non_akk.tsv | sort -h | uniq
# rg -woni -f /home/mibu/amniota_only_sp.list biosample_descr_non_akk.tsv | sort -h | uniq
# 7
# index for the list in python: 318
# 1
# index for the list in python: 311
# human            7
# gallus gallus    1
# Name: host, dtype: int64
#                                   Genome  Completeness  Contamination  \
# 2     GCA_000155695.1_ASM15569v1_genomic        100.00           1.35
# 3     GCA_000242935.3_ASM24293v3_genomic        100.00           0.23
# 4     GCA_000243495.3_ASM24349v3_genomic         98.63           0.23
# 7     GCA_000526255.1_ASM52625v1_genomic         98.65           0.68
# 8     GCA_000739615.1_ASM73961v1_genomic         99.86           2.72
# ..                                   ...           ...            ...
# 558        GCF_902726605.1_LCC19_genomic        100.00           2.03
# 559        GCF_902728225.1_LCC11_genomic        100.00           2.03
# 560  GCF_902728235.1_LCC4_PacBio_genomic         99.32           2.03
# 561        GCF_902728245.1_LCC21_genomic         99.16           2.03
# 562         GCF_902728255.1_LCC8_genomic         99.16           2.03
#
#                                         classification  \
# 2    d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 3    d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 4    d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 7    d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 8    d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# ..                                                 ...
# 558  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 559  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 560  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 561  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 562  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
#
#                                  classification_method  sum_len      N50  \
# 2    taxonomic classification defined by topology a...  5775745  5514226
# 3    taxonomic classification defined by topology a...  7417673  7317842
# 4    taxonomic classification defined by topology a...  7073483  6196881
# 7    taxonomic classification defined by topology a...  2465519  1285429
# 8    taxonomic classification defined by topology a...  7795129   203667
# ..                                                 ...      ...      ...
# 558  taxonomic classification defined by topology a...  4878525   109520
# 559  taxonomic classification defined by topology a...  4879546   130068
# 560  taxonomic classification defined by topology a...  4871565  3986899
# 561  taxonomic classification defined by topology a...  4884521   148072
# 562  taxonomic classification defined by topology a...  4886160   168040
#
#      16S ribosomal RNA > 1400 nt  Total_tRNAs host   NCBI_organism_name  \
# 2                            1.0           45  NaN                  NaN
# 3                            1.0           52  NaN                  NaN
# 4                            1.0           71  NaN                  NaN
# 7                            1.0           48  NaN                  NaN
# 8                            1.0           52  NaN                  NaN
# ..                           ...          ...  ...                  ...
# 558                          1.0           48  NaN  Lentimonas sp. CC19
# 559                          1.0           49  NaN  Lentimonas sp. CC11
# 560                          3.0           53  NaN   Lentimonas sp. CC4
# 561                          1.0           47  NaN  Lentimonas sp. CC21
# 562                          1.0           47  NaN   Lentimonas sp. CC8
#
#     NCBI_infraspecific_name relation_to_type_material type_of_sample
# 2                       NaN                       NaN            NaN
# 3                       NaN                       NaN            NaN
# 4                       NaN                       NaN            NaN
# 7                       NaN                       NaN            NaN
# 8                       NaN                       NaN            NaN
# ..                      ...                       ...            ...
# 558                     NaN                       NaN            NaN
# 559                     NaN                       NaN            NaN
# 560                     NaN                       NaN            NaN
# 561                     NaN                       NaN            NaN
# 562                     NaN                       NaN            NaN
#
# [384 rows x 14 columns]

# %%
(merged_non_akk['host'].value_counts(), 
 merged_non_akk['type_of_sample'].value_counts(), merged_non_akk['type_of_sample'].isna().sum())
# Out:
# (human            7
#  gallus gallus    1
#  Name: host, dtype: int64,
#  Series([], Name: type_of_sample, dtype: int64),
#  384)

# %% [markdown]
# # End `host`

# %% [markdown]
# # Set `type_of_sample`

# %%
regex = ("'isolate|isolated|culture|cultured|cultivation'")
ln_culture_non_akk = build_line_source('biosample_descr_non_akk.tsv', regex, file_pattern=False)
print(repr(ln_culture_non_akk[:200]))
acc_culture_non_akk = build_acc_host(ln_culture_non_akk, 'biosample_descr_non_akk.tsv')
print(set(acc_culture_non_akk.values()), len(acc_culture_non_akk))
# Out:
# rg -woni 'isolate|isolated|culture|cultured|cultivation' biosample_descr_non_akk.tsv | sort -h | uniq
# '44:culture\n45:culture\n46:culture\n111:culture\n158:culture\n334:culture\n336:culture\n337:culture\n338:culture\n339:culture\n350:isolate\n352:culture\n353:culture\n356:culture\n357:culture\n360:culture\n363:isolate'
# 22
# index for the list in python: 369
# {'isolated', 'isolate', 'culture'} 22

# %%
acc_culture_non_akk
# Out:
# defaultdict(None,
#             {'GCA_003054655.1': 'culture',
#              'GCA_003054665.1': 'culture',
#              'GCA_003054695.1': 'culture',
#              'GCA_013391475.1': 'culture',
#              'GCA_017305195.1': 'culture',
#              'GCF_001746835.1': 'culture',
#              'GCF_002954445.1': 'culture',
#              'GCF_003054705.1': 'culture',
#              'GCF_003185655.1': 'culture',
#              'GCF_004118375.1': 'culture',
#              'GCF_007559335.1': 'isolate',
#              'GCF_011044495.1': 'culture',
#              'GCF_011044775.1': 'culture',
#              'GCF_014230085.1': 'culture',
#              'GCF_014230145.1': 'culture',
#              'GCF_014803405.1': 'culture',
#              'GCF_016595465.1': 'isolated',
#              'GCF_016595505.1': 'isolated',
#              'GCF_016595555.1': 'isolated',
#              'GCF_017310505.1': 'isolate',
#              'GCF_017310525.1': 'isolate',
#              'GCF_017310545.1': 'isolate'})

# %% [markdown]
# ## Search for terms that are indicative of metagenomic samples

# %%
regex = ("'metagenome|metagenomic|microbiome|biome|gut|bucal|respiratory|mud|forest"
         "soil|sludge|water|marine|ocean|sediment|seawater|freshwater|freshwaters|feces|fecal|uncultured'")
ln_meta_non_akk = build_line_source('biosample_descr_non_akk.tsv', regex, file_pattern=False)
print(repr(ln_meta_non_akk[:200]))
acc_meta_non_akk = build_acc_host(ln_meta_non_akk, 'biosample_descr_non_akk.tsv')
print(set(acc_meta_non_akk.values()), len(acc_meta_non_akk))
# Out:
# rg -woni 'metagenome|metagenomic|microbiome|biome|gut|bucal|respiratory|mud|forestsoil|sludge|water|marine|ocean|sediment|seawater|freshwater|freshwaters|feces|fecal|uncultured' biosample_descr_non_akk.tsv | sort -h | uniq
# '7:freshwater\n7:Freshwater\n7:water\n8:metagenome\n8:metagenomic\n9:metagenome\n9:metagenomic\n10:biome\n10:freshwater\n10:Freshwater\n10:metagenome\n10:metagenomic\n11:marine\n11:metagenome\n11:metagenomic\n11:wate'
# 346
# index for the list in python: 383
# {'gut', 'uncultured', 'freshwater', 'metagenome', 'mud', 'seawater', 'metagenomic', 'microbiome', 'water', 'ocean', 'sludge', 'marine', 'sediment', 'feces'} 346

# %% [markdown]
# ### Which lines are in common between culture and metagenomic indicative samples?
# Check those descriptions

# %%
n_meta = {int(n.split(':')[0]) for n in ln_meta_non_akk.strip().split('\n')}
n_culture = {int(n.split(':')[0]) for n in ln_culture_non_akk.strip().split('\n')}
print(len(n_meta), len(n_culture))
n_meta & n_culture
# Out:
# 346 22
# {111, 158, 334, 336, 338, 339, 350, 357, 360, 363, 365, 367, 368, 369}

# %%
with open('biosample_descr_non_akk.tsv', 'r') as fh:
    biosample_non_akk_desc = fh.readlines()

# %%
(n_meta & n_culture)
# Out:
# {111, 158, 334, 336, 338, 339, 350, 357, 360, 363, 365, 367, 368, 369}

# %%
for n in (n_meta & n_culture):
    n = n - 1
    print(biosample_non_akk_desc[n])
# Out:
# GCF_007559335.1	SAMN10623051	53C-WASEF	freshwater creek	2018-04-17	Austria: Eugendorf	isolate	560 m	47.86 N 13.14 E	type strain of Rariglobus hedericola
#
# GCF_014230145.1	SAMN15676578	JCM23202	seawater	2020-05-30	Japan:Palau	cell culture	type strain of Pelagicoccus albus
#
# GCF_014803405.1	SAMN16205841	NFK12	sediment	2020-06-11	China: Weihai	mix culture	type strain of Pelagicoccus enzymogenes
#
# GCF_016595465.1	SAMN17169592	JCM 18052	2020-06-01	0	0	Activated sludge	not collected	not collected	not collected	not collected	not collected	1	Luteolibacter yonseiensis sp. nov., isolated from activated sludge using algal metabolites	type strain of Luteolibacter yonseiensis
#
# GCF_016595505.1	SAMN17169593	KCTC 13126	2020-09-30	0	0	Seawater	not collected	not collected	not collected	not collected	not collected	1	Pelagicoccus mobilis gen. nov., sp. nov., Pelagicoccus albus sp. nov. and Pelagicoccus litoralis sp. nov., three novel members of subdivision 4 within the phylum 'Verrucomicrobia', isolated from seawater by in situ cultivation.	type strain of Pelagicoccus mobilis
#
# GCF_001746835.1	SAMN04880612	IG16b	limnic surface water	2012-08-30	Germany: Wolfenbuettel	cell culture	type strain of Lacunisphaera limnophila
#
# GCA_013391475.1	SAMN15363799	N1E253	sediment	2018-09-11	China: Weihai	mix culture
#
# GCF_002954445.1	SAMN06090799	SAORIC-165	deep sea water	2011-02-27	Pacific Ocean: Northwestern Pacific Ocean station K2	culture	2000	10	type strain of Rubritalea profundi
#
# GCF_016595555.1	SAMN17169589	KCTC 12870	2020-09-30	0	0	Acid-treated sediment	not collected	China: Weihai	not collected	not collected	not collected	1	Cerasicoccus arenae gen. nov., sp. nov., a carotenoid-producing marine representative of the family Puniceicoccaceae within the phylum 'Verrucomicrobia', isolated from marine sand.	type strain of Cerasicoccus arenae
#
# GCF_003185655.1	SAMN08997837	WN38	sediment	2017-09-30	China:Weihai	pure culture	type strain of Coraliomargarita sinensis
#
# GCF_004118375.1	SAMN10780907	TWA-58	water	2018-06-24	Taiwan	cell culture	type material of Oleiharenicola lentus
#
# GCF_017310505.1	SAMN17036178	IT6	mud volcano	2017	Italy	isolate
#
# GCF_017310525.1	SAMN17036247	IT5	mud volcano	2017	Italy	isolate
#
# GCA_017305195.1	SAMN18061515	2014-10-30	biomaterial containment unit [ENVO:01001816]	bioreactor biome [ENVO:00002123]	anthropogenic environmental material [ENVO:0010001]	South Africa: Capetown	33.95 S 18.46 E	biofilm fraction from bioreactor innoculated with Activated Sludge Tailings Effluent Remediation (ASTER); culture conditions: molasses with increasing thiocyanate until 250 mg/L maintanence and no molasses	SCN18_30_10_14_R3_B_61_17	This BioSample is a metagenomic assembly obtained from the bioreactor metagenome BioSample SAMN17179661	1	1	metagenomic assembly	bioreactor metagenome	biofilm	molasses with increasing thiocyanate until 250 mg/L maintanence and no molasses

# %% [markdown]
# **From above, `GCA_013391475.1	SAMN15363799` , `GCA_017305195.1	SAMN18061515` and `GCF_014803405.1	SAMN16205841` are metagenomic, the rest seems to be `culture`, so all except these 3 have to be taken off from `acc_meta_non_akk`**

# %%
meta_asm = ['GCA_013391475.1', 'GCA_017305195.1', 'GCF_014803405.1']
asms = []
for n in (n_meta & n_culture):
    n = n - 1
    acc = biosample_non_akk_desc[n].split('\t')[0]
    if biosample_non_akk_desc[n].split('\t')[0] in meta_asm:
        continue
    else:
        asms.append(acc)
print(asms)
for asm in asms:
    acc_meta_non_akk.pop(asm)
len(acc_meta_non_akk)#3346 is the original  length
# Out:
# ['GCF_007559335.1', 'GCF_014230145.1', 'GCF_016595465.1', 'GCF_016595505.1', 'GCF_001746835.1', 'GCF_002954445.1', 'GCF_016595555.1', 'GCF_003185655.1', 'GCF_004118375.1', 'GCF_017310505.1', 'GCF_017310525.1']
# 335

# %%
add_info_to_summary(merged_non_akk,'type_of_sample', acc_culture_non_akk)
# Out:
# metagenome    332
# culture        15
# isolate         4
# isolated        3
# Name: type_of_sample, dtype: int64
# 0

# %%
common_to_sp  = {'isolate':'culture', 'isolated':'culture'}
merged_non_akk['type_of_sample'].replace(common_to_sp, inplace=True)
merged_non_akk['type_of_sample'].value_counts(), merged_non_akk['type_of_sample'].isna().sum()
# Out:
# (metagenome    332
#  culture        22
#  Name: type_of_sample, dtype: int64,
#  30)

# %% [markdown]
# ### Add these "sources" to `type_of_sample`

# %%
add_info_to_summary(merged_non_akk,'type_of_sample', acc_meta_non_akk)
# Out:
# water          198
# metagenomic     59
# sediment        30
# culture         19
# sludge          15
# microbiome       8
# ocean            5
# seawater         5
# metagenome       5
# marine           3
# gut              3
# uncultured       2
# feces            1
# mud              1
# Name: type_of_sample, dtype: int64
#                                   Genome  Completeness  Contamination  \
# 2     GCA_000155695.1_ASM15569v1_genomic        100.00           1.35
# 3     GCA_000242935.3_ASM24293v3_genomic        100.00           0.23
# 4     GCA_000243495.3_ASM24349v3_genomic         98.63           0.23
# 7     GCA_000526255.1_ASM52625v1_genomic         98.65           0.68
# 8     GCA_000739615.1_ASM73961v1_genomic         99.86           2.72
# ..                                   ...           ...            ...
# 558        GCF_902726605.1_LCC19_genomic        100.00           2.03
# 559        GCF_902728225.1_LCC11_genomic        100.00           2.03
# 560  GCF_902728235.1_LCC4_PacBio_genomic         99.32           2.03
# 561        GCF_902728245.1_LCC21_genomic         99.16           2.03
# 562         GCF_902728255.1_LCC8_genomic         99.16           2.03
#
#                                         classification  \
# 2    d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 3    d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 4    d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 7    d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 8    d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# ..                                                 ...
# 558  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 559  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 560  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 561  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 562  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
#
#                                  classification_method  sum_len      N50  \
# 2    taxonomic classification defined by topology a...  5775745  5514226
# 3    taxonomic classification defined by topology a...  7417673  7317842
# 4    taxonomic classification defined by topology a...  7073483  6196881
# 7    taxonomic classification defined by topology a...  2465519  1285429
# 8    taxonomic classification defined by topology a...  7795129   203667
# ..                                                 ...      ...      ...
# 558  taxonomic classification defined by topology a...  4878525   109520
# 559  taxonomic classification defined by topology a...  4879546   130068
# 560  taxonomic classification defined by topology a...  4871565  3986899
# 561  taxonomic classification defined by topology a...  4884521   148072
# 562  taxonomic classification defined by topology a...  4886160   168040
#
#      16S ribosomal RNA > 1400 nt  Total_tRNAs host   NCBI_organism_name  \
# 2                            1.0           45  NaN                  NaN
# 3                            1.0           52  NaN                  NaN
# 4                            1.0           71  NaN                  NaN
# 7                            1.0           48  NaN                  NaN
# 8                            1.0           52  NaN                  NaN
# ..                           ...          ...  ...                  ...
# 558                          1.0           48  NaN  Lentimonas sp. CC19
# 559                          1.0           49  NaN  Lentimonas sp. CC11
# 560                          3.0           53  NaN   Lentimonas sp. CC4
# 561                          1.0           47  NaN  Lentimonas sp. CC21
# 562                          1.0           47  NaN   Lentimonas sp. CC8
#
#     NCBI_infraspecific_name relation_to_type_material type_of_sample
# 2                       NaN                       NaN            NaN
# 3                       NaN                       NaN            NaN
# 4                       NaN                       NaN            NaN
# 7                       NaN                       NaN            NaN
# 8                       NaN                       NaN            NaN
# ..                      ...                       ...            ...
# 558                     NaN                       NaN          water
# 559                     NaN                       NaN          water
# 560                     NaN                       NaN          water
# 561                     NaN                       NaN          water
# 562                     NaN                       NaN          water
#
# [384 rows x 14 columns]

# %%
common_to_sp  = {'isolate':'culture', 'isolated':'culture'}
merged_non_akk['type_of_sample'].replace(common_to_sp, inplace=True)
merged_non_akk['type_of_sample'].value_counts(), merged_non_akk['type_of_sample'].isna().sum()
# Out:
# (metagenome    332
#  culture        22
#  Name: type_of_sample, dtype: int64,
#  30)

# %%
merged_non_akk['type_of_sample'].value_counts()
# Out:
# metagenome    335
# culture        19
# Name: type_of_sample, dtype: int64

# %% [markdown]
# ## When adding metagenome after `culture`, we get 19 `culture` instead of 22, check why those are changed

# %%
add_info_to_summary(merged_non_akk,'type_of_sample', acc_culture_non_akk)
# Out:
# metagenome    332
# culture        15
# isolate         4
# isolated        3
# Name: type_of_sample, dtype: int64
# 0

# %%
common_to_sp  = {'isolate':'culture', 'isolated':'culture'}
merged_non_akk['type_of_sample'].replace(common_to_sp, inplace=True)
merged_non_akk['type_of_sample'].value_counts(), merged_non_akk['type_of_sample'].isna().sum()
# Out:
# (metagenome    332
#  culture        22
#  Name: type_of_sample, dtype: int64,
#  30)

# %% [markdown]
# ## Create a dictionary with line numbers as keys and list of sources as values and use it with `build_acc_host_fromdict()`
#
# All the sources should be lower case

# %%
ln_meta_non_akk_dic = defaultdict(list)
for l in ln_meta_non_akk.strip().split('\n'):
    ln_meta_non_akk_dic[int(l.split(':')[0])].append(l.split(':')[1].lower() )
# print unique sources
{v for ls in ln_meta_non_akk_dic.values() for v in ls}
# Out:
# {'biome',
#  'feces',
#  'freshwater',
#  'freshwaters',
#  'gut',
#  'marine',
#  'metagenome',
#  'metagenomic',
#  'microbiome',
#  'mud',
#  'ocean',
#  'seawater',
#  'sediment',
#  'sludge',
#  'uncultured',
#  'water'}

# %% [markdown]
# ## Which lines that have `water` also have `marine` or `freshwater`?

# %% [markdown]
# ## These can be set as `marine water`

# %%
temp_dic = defaultdict()
for k,v in ln_meta_non_akk_dic.items():
    if 'water' in v and ('marine' in v or 'seawater' in v or 'ocean' in v):
        temp_dic[k] = v
        #         print(k,v)
acc_custom_non_akk = build_acc_host_fromdict(temp_dic, 'biosample_descr_non_akk.tsv', 'marine water')
add_info_to_summary(merged_non_akk,'host', acc_custom_non_akk)
# Out:
# 34
# index for the list in python: 383
# sediment        197
# marine water    149
# Name: host, dtype: int64
# 0

# %% [markdown]
# ## These can be set as `freshwaters`

# %%
temp_dic = defaultdict()
for k,v in ln_meta_non_akk_dic.items():
    if 'freshwater' in v or 'freshwaters' in v:
#         print(k,v)
        temp_dic[k] = v
acc_custom_non_akk = build_acc_host_fromdict(temp_dic, 'biosample_descr_non_akk.tsv', 'freshwaters')
add_info_to_summary(merged_non_akk,'host', acc_custom_non_akk)
# Out:
# 169
# index for the list in python: 349
# freshwaters     169
# marine water    149
# sediment         28
# Name: host, dtype: int64
# 0

# %% [markdown]
# ## These can be set as `sediment`
#
# Here, some samples will go from marine water to sediment

# %%
temp_dic = defaultdict()
for k,v in ln_meta_non_akk_dic.items():
    if 'sediment' in v:
#         print(k,v)
        temp_dic[k] = v
acc_custom_non_akk = build_acc_host_fromdict(temp_dic, 'biosample_descr_non_akk.tsv', 'sediment')
add_info_to_summary(merged_non_akk,'host', acc_custom_non_akk)
# Out:
# 33
# index for the list in python: 366
# freshwaters     164
# marine water    149
# sediment         33
# Name: host, dtype: int64
# 0

# %% [markdown]
# ## These can be set as `freshwaters sediment` and `marine water sediment`
#
# Here, some samples will go from marine water to sediment

# %%
temp_dic = defaultdict()
for k,v in ln_meta_non_akk_dic.items():
    if 'sediment' in v  and ('freshwater' in v or 'freshwaters' in v):
#         print(k,v)
        temp_dic[k] = v
acc_custom_non_akk = build_acc_host_fromdict(temp_dic, 'biosample_descr_non_akk.tsv', 'freshwaters sediment')
add_info_to_summary(merged_non_akk,'host', acc_custom_non_akk)
# Out:
# 5
# index for the list in python: 232
# freshwaters             164
# marine water            149
# sediment                 28
# freshwaters sediment      5
# Name: host, dtype: int64
# 0

# %%
temp_dic = defaultdict()
for k,v in ln_meta_non_akk_dic.items():
    if 'sediment' in v  and ('seawater' in v or 'marine' in v):
#         print(k,v)
        temp_dic[k] = v
acc_custom_non_akk = build_acc_host_fromdict(temp_dic, 'biosample_descr_non_akk.tsv', 'marine water sediment')
add_info_to_summary(merged_non_akk,'host', acc_custom_non_akk)
# Out:
# 5
# index for the list in python: 366
# freshwaters              164
# marine water             149
# sediment                  23
# marine water sediment      5
# freshwaters sediment       5
# Name: host, dtype: int64
# 0

# %%
merged_non_akk['host'].value_counts(), merged_non_akk['host'].isna().sum()
# Out:
# (freshwaters              164
#  marine water             149
#  sediment                  23
#  marine water sediment      5
#  freshwaters sediment       5
#  Name: host, dtype: int64,
#  38)

# %%
merged_non_akk['type_of_sample'].value_counts(), merged_non_akk['type_of_sample'].isna().sum()
# Out:
# (metagenome    332
#  culture        22
#  Name: type_of_sample, dtype: int64,
#  30)

# %%
merged_non_akk.to_csv(qc_path.joinpath('merged_non_akk.tsv'), sep='\t', index=False)

# %%
nan_type = merged_non_akk[merged_non_akk['type_of_sample'].isna()].loc[:, 'Genome'].str.extract('(GC[AF]_[0-9]{9}\.[1-9]{1,2})').dropna().values.flatten()
nan_host = merged_non_akk[merged_non_akk['host'].isna()].loc[:, 'Genome'].str.extract('(GC[AF]_[0-9]{9}\.[1-9]{1,2})').dropna().values.flatten()
len(set(nan_host) | set(nan_type))
# Out:
# 38

# %%
fh = open('bioproject_descr_miss_biosam_non_akk.tsv', 'a')
asms = set(nan_type.tolist() + nan_host.tolist())
for idx,row in asm_biosam_bioproj.set_index('assembly_accession').loc[asms, :].iterrows():
    bp = row['bioproject']
    desc = ! esearch -db bioproject -query $bp | efetch -format docsum |  xtract -pattern DocumentSummary -element Project_Name,Project_Title,Project_Description,Project_Target_Scope
    desc_ls = desc.get_spstr().split('\t')
    desc_ls.insert(0, row['bioproject'])
    desc_ls.insert(0, row['biosample'])
    desc_ls.insert(0, idx)#assembly accession
    print('\t'.join(desc_ls), file=fh)
fh.close()
# Out:
# ^C
# ^C
# ^C
# ^C
# ^C
# ^C
# ^C
# ^C
# ^C
# ^C
# ^C
# ^C
# ^C
# ^C
# ^C
# ^C
# ^C
# ^C
# ^C
# ^C
# ^C

# %%
with open('bioproject_descr_miss_biosam_non_akk.tsv', 'r') as fh:
        bioproj_desc_miss = fh.readlines()
for l in bioproj_desc_miss:
    print(l)
# Out:
# GCF_014651675.1	SAMD00245577	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_000817245.1	SAMN02996356	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCA_000243495.3	SAMN02261400	PRJNA62139	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_000379365.1	SAMN02256457	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_900141815.1	SAMN02745181	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_004341915.1	SAMN10866388	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_000172555.1	SAMN00000631	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_014201715.1	SAMN14908355	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_900104925.1	SAMN05444173	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCA_003054665.1	SAMN08724138	PRJNA438699	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCA_003054655.1	SAMN08724137	PRJNA438699	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_004364345.1	SAMN02745162	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_007992435.1	SAMD00172670	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_014230085.1	SAMN15676579	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_900105685.1	SAMN05444156	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCA_000739655.1	SAMD00036768	PRJDB1469	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCA_000155695.1	SAMN02436317	PRJNA19391	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_902143385.2	SAMEA5600708	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_011044775.1	SAMN14102279	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_001613545.1	SAMD00048637	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_000297415.1	SAMEA2272587	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_000172155.1	SAMN02436175	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_902143375.2	SAMEA5600707	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_000019965.1	SAMN00000285	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_900167535.1	SAMN02745166	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_007475525.1	SAMN08451303	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_014651635.1	SAMD00245575	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_000019665.1	SAMN02604183	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_000173075.1	SAMN00000678	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCA_016811075.1	SAMN17711332	PRJNA698280	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_017310545.1	SAMN17073650	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCA_000739615.1	SAMD00036766	PRJDB1467	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCA_003054695.1	SAMN08724136	PRJNA438699	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCA_000526255.1	SAMN02584925	PRJNA185245	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_003054705.1	SAMN08724139	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCA_000242935.3	SAMN02261410	PRJNA63271	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_011044495.1	SAMN14143996	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_012913485.1	SAMN14642216	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_014651675.1	SAMD00245577	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_000817245.1	SAMN02996356	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCA_000243495.3	SAMN02261400	PRJNA62139	Opitutaceae bacterium TAV1	Opitutaceae bacterium TAV1 genome sequencing	This strain will be used for comparative analysis.
#
# GCF_000379365.1	SAMN02256457	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_900141815.1	SAMN02745181	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_004341915.1	SAMN10866388	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_000172555.1	SAMN00000631	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_014201715.1	SAMN14908355	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_900104925.1	SAMN05444173	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCA_003054665.1	SAMN08724138	PRJNA438699	Genomic and phenotypic characterization of four novel plant-associated Verrucomicrobia indicate a new subdivision with one cultivated member	Genomic and physiological description of new isolates (Verrucomicrobia) from O.sativa and O.longistaminata. Analysis of physiology and genomic context with focus on microbe-plant interactions.
#
# GCA_003054655.1	SAMN08724137	PRJNA438699	Genomic and phenotypic characterization of four novel plant-associated Verrucomicrobia indicate a new subdivision with one cultivated member	Genomic and physiological description of new isolates (Verrucomicrobia) from O.sativa and O.longistaminata. Analysis of physiology and genomic context with focus on microbe-plant interactions.
#
# GCF_004364345.1	SAMN02745162	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_007992435.1	SAMD00172670	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_014230085.1	SAMN15676579	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_900105685.1	SAMN05444156	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCA_000739655.1	SAMD00036768	PRJDB1469	Verrucomicrobium sp. BvORR106	Genome sequence of Verrucomicrobium sp. BvORR106	A sequencing for draft genome of a Verrucomicrobia bacgterium isolated from main roots of sugar beet was conducted in ordet to analyze the functionality of plant-associated Verrucomicrobia bacteria. The sequence data will be used for clarifying the molecular interaction between a plant and a Verrucomicrobia bacterium
#
# GCA_000155695.1	SAMN02436317	PRJNA19391	Verrucomicrobiae bacterium DG1235	A culturable pelagic Verrucomicrobia isolated from a dinoflagellate	Verrucomicrobiae bacterium DG1235. The genome analysis of this strain will allow a comprehensive investigation of the metabolic potential and involvement in biogeochemical cycling of this abundant, but underrepresented group of organisms in the marine environment.
#
# GCF_902143385.2	SAMEA5600708	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_011044775.1	SAMN14102279	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_001613545.1	SAMD00048637	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_000297415.1	SAMEA2272587	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_000172155.1	SAMN02436175	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_902143375.2	SAMEA5600707	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_000019965.1	SAMN00000285	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_900167535.1	SAMN02745166	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_007475525.1	SAMN08451303	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_014651635.1	SAMD00245575	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_000019665.1	SAMN02604183	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_000173075.1	SAMN00000678	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCA_016811075.1	SAMN17711332	PRJNA698280	Verrucomicrobiaceae bacterium 5K15	Verrucomicrobiaceae bacterium 5K15 Genome sequencing and assembly	Used for the study of Verrucomicrobia
#
# GCF_017310545.1	SAMN17073650	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCA_000739615.1	SAMD00036766	PRJDB1467	Haloferula sp. BvORR071	Genome sequence of Haloferula sp. BvORR071	A sequencing for draft genome of a Verrucomicrobia bacgterium isolated from main roots of sugar beet was conducted in ordet to analyze the functionality of plant-associated Verrucomicrobia bacteria. The sequence data will be used for clarifying the molecular interaction between a plant and a Verrucomicrobia bacterium
#
# GCA_003054695.1	SAMN08724136	PRJNA438699	Genomic and phenotypic characterization of four novel plant-associated Verrucomicrobia indicate a new subdivision with one cultivated member	Genomic and physiological description of new isolates (Verrucomicrobia) from O.sativa and O.longistaminata. Analysis of physiology and genomic context with focus on microbe-plant interactions.
#
# GCA_000526255.1	SAMN02584925	PRJNA185245	Verrucomicrobia bacterium LP2A	Verrucomicrobia bacterium LP2A Genome sequencing and assembly	Revising methanotrophy: a comprehensive genomic probing of the unexpected genetic and metabolic diversity of aerobic methane consuming bacteria.
#
# GCF_003054705.1	SAMN08724139	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCA_000242935.3	SAMN02261410	PRJNA63271	Opitutaceae bacterium TAV5	Opitutaceae bacterium TAV5 genome sequencing project	Opitutaceae bacterium TAV5. This strain will be used for comparative genome analysis.
#
# GCF_011044495.1	SAMN14143996	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.
#
# GCF_012913485.1	SAMN14642216	PRJNA224116	Refseq Prokaryotic Genome Annotation Project	NCBI has developed an automatic annotation pipeline that combines ab initio gene prediction algorithms with homology based methods. See more details here. Historically RefSeq prokaryotic genomes retained on author submitted annotation. Annotation from different submitters varies in quality resulting in the inconsistent annotation even in closely related genomes. The NCBI Prokaryotic Annotation Pipeline can produce consistent high quality automatic annotation.

# %% [markdown]
# ## From the above, most but no all the information is from projects referred as *Refseq Prokaryotic Genome Annotation Project*

# %% [markdown]
# # BioProject `host`

# %%
ln_comm_sp_bp =  build_line_source('bioproject_descr_miss_biosam_non_akk.tsv', common_pats, file_pattern=True)
ln_sp_bp =  build_line_source('bioproject_descr_miss_biosam_non_akk.tsv', sp_pats, file_pattern=True)
print(ln_comm_sp_bp, ln_sp_bp)
assert ln_comm_sp_bp != ''
assert ln_sp_bp != ''
# acc_comm_sp_bp = build_acc_host(ln_comm_sp_bp, 'bioproject_descr_miss_biosam_non_akk.tsv')
# acc_sp_bp = build_acc_host(ln_sp_bp, 'bioproject_descr_miss_biosam_non_akk.tsv')
# add_info_to_summary(merged_non_akk, 'host', acc_comm_sp_bp, acc_sp_bp)
# Out:
# rg -woni -f /home/mibu/common_names_ncbi.list bioproject_descr_miss_biosam_non_akk.tsv | sort -h | uniq
# rg -woni -f /home/mibu/amniota_only_sp.list bioproject_descr_miss_biosam_non_akk.tsv | sort -h | uniq
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-588-eeb9a28c4375> in <module>
#       2 ln_sp_bp =  build_line_source('bioproject_descr_miss_biosam_non_akk.tsv', sp_pats, file_pattern=True)
#       3 print(ln_comm_sp_bp, ln_sp_bp)
# ----> 4 assert ln_comm_sp_bp != ''
#       5 assert ln_sp_bp != ''
#       6 # acc_comm_sp_bp = build_acc_host(ln_comm_sp_bp, 'bioproject_descr_miss_biosam_non_akk.tsv')
#
# AssertionError:

# %% [markdown]
# **So no host/species information from bioproject**

# %% [markdown]
# # Set `type_of_sample`

# %%
regex = ("'isolate|isolated|isolates|monoisolate|culture|cultured|cultivation|cultivated'")
ln_culture_non_akk_bp = build_line_source('bioproject_descr_miss_biosam_non_akk.tsv', regex, file_pattern=False)
print(repr(ln_culture_non_akk_bp[:200]))
acc_culture_non_akk_bp = build_acc_host(ln_culture_non_akk_bp, 'bioproject_descr_miss_biosam_non_akk.tsv')
print(set(acc_culture_non_akk_bp.values()), len(acc_culture_non_akk_bp))
# Out:
# rg -woni 'isolate|isolated|isolates|culture|cultured|cultivation|cultivated' bioproject_descr_miss_biosam_non_akk.tsv | sort -h | uniq
# '48:cultivated\n48:isolates\n49:cultivated\n49:isolates\n54:isolated\n55:isolated\n70:isolated\n71:cultivated\n71:isolates\n'
# 6
# index for the list in python: 70
# {'isolated', 'isolates'} 6

# %%
add_info_to_summary(merged_non_akk,'type_of_sample', acc_culture_non_akk_bp)
# Out:
# metagenome    332
# culture        19
# isolated        3
# isolates        3
# Name: type_of_sample, dtype: int64
# 0

# %%
common_to_sp  = {'isolate':'culture', 'isolated':'culture', 'isolates':'culture'}
merged_non_akk['type_of_sample'].replace(common_to_sp, inplace=True)
merged_non_akk['type_of_sample'].value_counts(), merged_non_akk['type_of_sample'].isna().sum()
# Out:
# (metagenome    332
#  culture        25
#  Name: type_of_sample, dtype: int64,
#  27)

# %%
regex = ("'metagenome|metagenomic|microbiome|biome|gut|bucal|respiratory|mud|forest"
         "soil|sludge|water|marine|ocean|sediment|seawater|freshwater|freshwaters|feces|fecal|uncultured'")
ln_meta_non_akk_bp = build_line_source('bioproject_descr_miss_biosam_non_akk.tsv', regex, file_pattern=False)
print(repr(ln_meta_non_akk_bp))
# acc_meta_non_akk_bp = build_acc_host(ln_meta_non_akk, 'bioproject_descr_miss_biosam_non_akk.tsv')
# print(set(acc_meta_non_akk_bp.values()), len(acc_meta_non_akk_bp))
# Out:
# rg -woni 'metagenome|metagenomic|microbiome|biome|gut|bucal|respiratory|mud|forestsoil|sludge|water|marine|ocean|sediment|seawater|freshwater|freshwaters|feces|fecal|uncultured' bioproject_descr_miss_biosam_non_akk.tsv | sort -h | uniq
# '55:marine\n'

# %%
len(ln_meta_non_akk_bp.strip().splitlines())
# Out:
# 1

# %% [markdown]
# Only one hit, can be added manually

# %% [markdown]
# ### Assign those samples that are representatives, `relation_to_type_material == assembly from type material` to `type_of_sample` = `culture`

# %%
mask = ~merged_non_akk['relation_to_type_material'].isna()
merged_non_akk.loc[mask, 'type_of_sample'] = 'culture'

# %%
merged_non_akk.to_csv(qc_path.joinpath('merged_non_akk.tsv'), sep='\t', index=False)

# %%
ncbi_df.info()
ncbi_df['relation_to_type_material'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1158218 entries, 0 to 1158217
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Genome                     1158163 non-null  object
#  1   assembly_accession         1158218 non-null  object
#  2   bioproject                 1158214 non-null  object
#  3   biosample                  1158213 non-null  object
#  4   wgs_master                 1104090 non-null  object
#  5   refseq_category            1158218 non-null  object
#  6   taxid                      1158218 non-null  int64
#  7   species_taxid              1158218 non-null  int64
#  8   NCBI_organism_name         1158218 non-null  object
#  9   NCBI_infraspecific_name    998033 non-null   object
#  10  isolate                    182630 non-null   object
#  11  version_status             1158218 non-null  object
#  12  assembly_level             1158218 non-null  object
#  13  release_type               1158218 non-null  object
#  14  genome_rep                 1158218 non-null  object
#  15  seq_rel_date               1158218 non-null  object
#  16  asm_name                   1158217 non-null  object
#  17  submitter                  1158210 non-null  object
#  18  gbrs_paired_asm            1158218 non-null  object
#  19  paired_asm_comp            1158218 non-null  object
#  20  ftp_path                   1158218 non-null  object
#  21  excluded_from_refseq       726985 non-null   object
#  22  relation_to_type_material  32556 non-null    object
# dtypes: int64(2), object(21)
# memory usage: 203.2+ MB
# array([None, 'assembly from type material',
#        'assembly from synonym type material',
#        'assembly from pathotype material',
#        'assembly designated as neotype', 'assembly designated as reftype'],
#       dtype=object)

# %%
not_nans_type = merged_akk[~merged_akk['relation_to_type_material'].isna()].loc[:, 'Genome'].values.flatten()
merged_akk.set_index('Genome').loc[not_nans_type]
# not_nans_type
# ncbi_df.set_index('assembly_accession').loc[not_nans_type].loc[:, 'relation_to_type_material'].unique()
# Out:
#                                       Completeness  Contamination  \
# Genome
# GCF_000020225.1_ASM2022v1_genomic            97.96           0.00
# GCF_008000975.1_ASM800097v1_genomic          97.96           0.00
# GCF_017504145.1_ASM1750414v1_genomic         97.96           0.00
# GCF_001683795.1_ASM168379v1_genomic          91.84           4.76
#
#                                                                          classification  \
# Genome
# GCF_000020225.1_ASM2022v1_genomic     d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# GCF_008000975.1_ASM800097v1_genomic   d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# GCF_017504145.1_ASM1750414v1_genomic  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# GCF_001683795.1_ASM168379v1_genomic   d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
#
#                                                                   classification_method  \
# Genome
# GCF_000020225.1_ASM2022v1_genomic     taxonomic classification defined by topology a...
# GCF_008000975.1_ASM800097v1_genomic   taxonomic classification defined by topology a...
# GCF_017504145.1_ASM1750414v1_genomic  taxonomic classification defined by topology a...
# GCF_001683795.1_ASM168379v1_genomic   taxonomic classification defined by topology a...
#
#                                       sum_len      N50  \
# Genome
# GCF_000020225.1_ASM2022v1_genomic     2664102  2664102
# GCF_008000975.1_ASM800097v1_genomic   2664043  2664043
# GCF_017504145.1_ASM1750414v1_genomic  2664051  2664051
# GCF_001683795.1_ASM168379v1_genomic   3157849   127311
#
#                                       16S ribosomal RNA > 1400 nt  \
# Genome
# GCF_000020225.1_ASM2022v1_genomic                             3.0
# GCF_008000975.1_ASM800097v1_genomic                           3.0
# GCF_017504145.1_ASM1750414v1_genomic                          3.0
# GCF_001683795.1_ASM168379v1_genomic                           NaN
#
#                                       Total_tRNAs                host  \
# Genome
# GCF_000020225.1_ASM2022v1_genomic              54                 NaN
# GCF_008000975.1_ASM800097v1_genomic            54        homo sapiens
# GCF_017504145.1_ASM1750414v1_genomic           54                 NaN
# GCF_001683795.1_ASM168379v1_genomic            42  reticulated python
#
#                                                         NCBI_organism_name  \
# Genome
# GCF_000020225.1_ASM2022v1_genomic     Akkermansia muciniphila ATCC BAA-835
# GCF_008000975.1_ASM800097v1_genomic                Akkermansia muciniphila
# GCF_017504145.1_ASM1750414v1_genomic  Akkermansia muciniphila ATCC BAA-835
# GCF_001683795.1_ASM168379v1_genomic               Akkermansia glycaniphila
#
#                                      NCBI_infraspecific_name  \
# Genome
# GCF_000020225.1_ASM2022v1_genomic        strain=ATCC BAA-835
# GCF_008000975.1_ASM800097v1_genomic         strain=DSM 22959
# GCF_017504145.1_ASM1750414v1_genomic     strain=ATCC BAA-835
# GCF_001683795.1_ASM168379v1_genomic               strain=Pyt
#
#                                         relation_to_type_material  \
# Genome
# GCF_000020225.1_ASM2022v1_genomic     assembly from type material
# GCF_008000975.1_ASM800097v1_genomic   assembly from type material
# GCF_017504145.1_ASM1750414v1_genomic  assembly from type material
# GCF_001683795.1_ASM168379v1_genomic   assembly from type material
#
#                                      type_of_sample
# Genome
# GCF_000020225.1_ASM2022v1_genomic           culture
# GCF_008000975.1_ASM800097v1_genomic         culture
# GCF_017504145.1_ASM1750414v1_genomic        culture
# GCF_001683795.1_ASM168379v1_genomic         culture

# %%
asm_biosam_bioproj[asm_biosam_bioproj['assembly_accession'] == 'GCF_000172555.1']
# Out:
#     assembly_accession     biosample   bioproject
# 358    GCF_000172555.1  SAMN00000631  PRJNA224116

# %% [markdown]
# ### Sometimes, an assembly may have more than one BioProject. The ones from the ncbi summary table are not neccesarily the most nformative. Check the project id inside `GB_BioProjects`
#
# Many times, the Bioproj from the summary tables,  refer to a project about ncbi annotation

# %%
! esearch -db assembly -query GCF_000172555.1 | efetch -format docsum |xtract -pattern DocumentSummary -block GB_BioProjects -element BioprojectAccn
# Out:
# PRJNA20839

# %% [markdown]
# ### Add a colummn with the `GB_BioProjects/BioprojectAccn` to `asm_biosam_bioproj`

# %%
asm_biosam_bioproj.head(2)
# Out:
#   assembly_accession     biosample  bioproject
# 0    GCA_000155695.1  SAMN02436317  PRJNA19391
# 1    GCA_000242935.3  SAMN02261410  PRJNA63271

# %%
for i, row in asm_biosam_bioproj.iterrows():
    asm = row['assembly_accession']
    bp = ! esearch -db assembly -query $asm | efetch -format docsum |xtract -pattern DocumentSummary -block GB_BioProjects -element BioprojectAccn
    print(bp)
    asm_biosam_bioproj.loc[i, 'GB_BioProjects'] = bp[0]
# Out:
# ['PRJNA19391']
# ['PRJNA63271']
# ['PRJNA62139']
# ['PRJEB726']
# ['PRJEB840']
# ['PRJNA185245']
# ['PRJDB1467']
# ['PRJDB1469']
# ['PRJNA279927']
# ['PRJNA297582']
# ['PRJNA279279']
# ['PRJNA321218']
# ['PRJNA238866']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA342151']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA348753']
# ['PRJNA391943']
# ['PRJNA391943']
# ['PRJNA391943']
# ['PRJNA391943']
# ['PRJNA391943']
# ['PRJNA391943']
# ['PRJNA362739']
# ['PRJNA362739']
# ['PRJNA362739']
# ['PRJNA438699']
# ['PRJNA438699']
# ['PRJNA438699']
# ['PRJNA386568']
# ['PRJNA386568']
# ['PRJNA386568']
# ['PRJNA386568']
# ['PRJNA386568']
# ['PRJNA386568']
# ['PRJNA386568']
# ['PRJNA386568']
# ['PRJNA386568']
# ['PRJNA386568']
# ['PRJNA386568']
# ['PRJNA386568']
# ['PRJNA386568']
# ['PRJNA386568']
# ['PRJNA386568']
# ['PRJNA386568']
# ['PRJNA386568']
# ['PRJNA386568']
# ['PRJNA386568']
# ['PRJNA449266']
# ['PRJNA449266']
# ['PRJNA454827']
# ['PRJNA417962']
# ['PRJNA434545']
# ['PRJNA434545']
# ['PRJNA448579']
# ['PRJNA448579']
# ['PRJNA448579']
# ['PRJNA448579']
# ['PRJNA514088']
# ['PRJNA531348']
# ['PRJNA453733']
# ['PRJNA453733']
# ['PRJNA453733']
# ['PRJNA453733']
# ['PRJNA453733']
# ['PRJNA453733']
# ['PRJNA512237']
# ['PRJNA492716']
# ['PRJNA492716']
# ['PRJNA480789']
# ['PRJNA363633']
# ['PRJNA512237']
# ['PRJNA544874']
# ['PRJNA525692']
# ['PRJNA525692']
# ['PRJNA428417']
# ['PRJNA428417']
# ['PRJNA604877']
# ['PRJNA605358']
# ['PRJNA480137']
# ['PRJNA480137']
# ['PRJNA480137']
# ['PRJNA480137']
# ['PRJNA480137']
# ['PRJNA480137']
# ['PRJNA480137']
# ['PRJNA480137']
# ['PRJNA480137']
# ['PRJNA480137']
# ['PRJNA598059']
# ['PRJNA545004']
# ['PRJNA602310']
# ['PRJNA602310']
# ['PRJNA522654']
# ['PRJNA522654']
# ['PRJNA623061']
# ['PRJNA482655']
# ['PRJNA641721']
# ['PRJNA630822']
# ['PRJDB6644']
# ['PRJNA613976']
# ['PRJNA649215']
# ['PRJNA649215']
# ['PRJNA574041']
# ['PRJNA574041']
# ['PRJNA574041']
# ['PRJNA562766']
# ['PRJNA562766']
# ['PRJNA562766']
# ['PRJNA562766']
# ['PRJNA562766']
# ['PRJNA562766']
# ['PRJNA562766']
# ['PRJNA562766']
# ['PRJNA562766']
# ['PRJNA576469']
# ['PRJNA576469']
# ['PRJNA576469']
# ['PRJNA627084']
# ['PRJNA627084']
# ['PRJNA488180']
# ['PRJNA623111']
# ['PRJNA640378']
# ['PRJNA640378']
# ['PRJNA640378']
# ['PRJNA640378']
# ['PRJNA640378']
# ['PRJNA640378']
# ['PRJNA640378']
# ['PRJNA640378']
# ['PRJNA663590']
# ['PRJNA663590']
# ['PRJNA688125']
# ['PRJNA688125']
# ['PRJNA629478']
# ['PRJNA629478']
# ['PRJNA638805']
# ['PRJNA592128']
# ['PRJNA592128']
# ['PRJNA592128']
# ['PRJNA592128']
# ['PRJNA592128']
# ['PRJNA592128']
# ['PRJNA592128']
# ['PRJNA592128']
# ['PRJNA698280']
# ['PRJNA523022']
# ['PRJNA523022']
# ['PRJNA523022']
# ['PRJNA523022']
# ['PRJNA523022']
# ['PRJNA690107']
# ['PRJNA690107']
# ['PRJNA629336']
# ['PRJNA704939']
# ['PRJEB26432']
# ['PRJEB26432']
# ['PRJEB26432']
# ['PRJEB26432']
# ['PRJEB31003']
# ['PRJEB31003']
# ['PRJEB31003']
# ['PRJEB31003']
# ['PRJEB31003']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB38681']
# ['PRJEB33338']
# ['PRJEB38020']
# ['PRJEB41592']
# ['PRJEB41592']
# ['PRJEB41592']
# ['PRJEB37358']
# ['PRJEB37358']
# ['PRJEB37358']
# ['PRJEB37358']
# ['PRJEB37358']
# ['PRJEB37358']
# ['PRJEB37358']
# ['PRJEB37358']
# ['PRJEB37358']
# ['PRJEB37358']
# ['PRJEB37358']
# ['PRJNA28995']
# ['PRJNA19989']
# ['PRJNA20089']
# ['PRJNA33365']
# ['PRJNA18333']
# ['PRJNA10620']
# ['PRJNA20839']
# ['PRJNA28531']
# ['PRJEA85607']
# ['PRJNA181370']
# ['PRJNA165235']
# ['PRJEB6027']
# ['PRJNA169117']
# ['PRJNA268324']
# ['PRJNA310109']
# ['PRJNA310109']
# ['PRJNA268325']
# ['PRJDB4647']
# ['PRJNA80821']
# ['PRJNA317592']
# ['PRJNA319155']
# ['PRJNA377666']
# ['PRJNA289613']
# ['PRJNA404023']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA331216']
# ['PRJNA355604']
# ['PRJNA438699']
# ['PRJNA454064']
# ['PRJNA417186']
# ['PRJNA417203']
# ['PRJNA417208']
# ['PRJNA417215']
# ['PRJNA429085']
# ['PRJNA429088']
# ['PRJNA429277']
# ['PRJNA429282']
# ['PRJNA429288']
# ['PRJNA429289']
# ['PRJNA429295']
# ['PRJNA429285']
# ['PRJNA429286']
# ['PRJNA429075']
# ['PRJNA429077']
# ['PRJNA429279']
# ['PRJNA429284']
# ['PRJNA429292']
# ['PRJNA429294']
# ['PRJNA494944']
# ['PRJNA516019']
# ['PRJNA496358']
# ['PRJNA523108']
# ['PRJNA520343']
# ['PRJNA245598']
# ['PRJNA320805']
# ['PRJNA320813']
# ['PRJNA320811']
# ['PRJNA320815']
# ['PRJNA320360']
# ['PRJNA320816']
# ['PRJNA540970']
# ['PRJNA432521']
# ['PRJNA510297']
# ['PRJDB6310']
# ['PRJNA559704']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA544527']
# ['PRJNA486904']
# ['PRJDB8988']
# ['PRJNA434535']
# ['PRJNA434536']
# ['PRJNA434602']
# ['PRJNA434603']
# ['PRJNA434605']
# ['PRJNA434606']
# ['PRJNA434607']
# ['PRJNA434609']
# ['PRJNA434608']
# ['PRJNA434610']
# ['PRJNA434611']
# ['PRJNA463453']
# ['PRJNA473879']
# ['PRJNA473880']
# ['PRJNA473884']
# ['PRJNA473885']
# ['PRJNA473887']
# ['PRJNA473889']
# ['PRJNA473890']
# ['PRJNA473891']
# ['PRJNA473892']
# ['PRJNA603250']
# ['PRJNA607683']
# ['PRJNA606647']
# ['PRJNA626486']
# ['PRJNA632309']
# ['PRJNA649666']
# ['PRJNA649666']
# ['PRJDB10508']
# ['PRJDB10508']
# ['PRJNA664317']
# ['PRJNA688125']
# ['PRJNA688125']
# ['PRJNA688125']
# ['PRJNA688125']
# ['PRJNA688125']
# ['PRJNA688125']
# ['PRJNA688125']
# ['PRJNA680355']
# ['PRJNA683735']
# ['PRJNA683748']
# ['PRJNA684964']
# ['PRJDB7416']
# ['PRJNA628672']
# ['PRJDB7416']
# ['PRJDB7416']
# ['PRJDB7416']
# ['PRJDB7416']
# ['PRJEB16366']
# ['PRJEB16461']
# ['PRJEB18286']
# ['PRJEB19594']
# ['PRJEB21068']
# ['PRJEB21068']
# ['PRJEB21068']
# ['PRJEB21068']
# ['PRJEB32513']
# ['PRJEB32513']
# ['PRJEB34624']
# ['PRJEB34624']
# ['PRJEB34624']
# ['PRJEB34624']
# ['PRJEB34624']
# ['PRJEB34624']
# ['PRJEB34624']
# ['PRJEB34624']
# ['PRJNA288964']
# ['PRJEB15121']
# ['PRJEB21068']

# %%
asm_biosam_bioproj[asm_biosam_bioproj['bioproject'] != asm_biosam_bioproj['GB_BioProjects']]
# Out:
#     assembly_accession       biosample   bioproject GB_BioProjects
# 352    GCF_000019665.1    SAMN02604183  PRJNA224116     PRJNA28995
# 353    GCF_000019965.1    SAMN00000285  PRJNA224116     PRJNA19989
# 354    GCF_000020225.1    SAMN00138213  PRJNA224116     PRJNA20089
# 355    GCF_000025905.1    SAMN02598501  PRJNA224116     PRJNA33365
# 356    GCF_000171235.2    SAMN02256391  PRJNA224116     PRJNA18333
# ..                 ...             ...          ...            ...
# 559    GCF_902728245.1    SAMEA6101986  PRJNA224116     PRJEB34624
# 560    GCF_902728255.1    SAMEA6101990  PRJNA224116     PRJEB34624
# 561    GCF_001683795.1    SAMN03840437  PRJNA224116    PRJNA288964
# 562    GCF_900097105.1    SAMEA4378782  PRJNA224116     PRJEB15121
# 563    GCF_900184965.1  SAMEA104102608  PRJNA224116     PRJEB21068
#
# [212 rows x 4 columns]

# %%
nan_type = merged_non_akk[merged_non_akk['type_of_sample'].isna()].loc[:, 'Genome'].str.extract('(GC[AF]_[0-9]{9}\.[1-9]{1,2})').dropna().values.flatten()
nan_host = merged_non_akk[merged_non_akk['host'].isna()].loc[:, 'Genome'].str.extract('(GC[AF]_[0-9]{9}\.[1-9]{1,2})').dropna().values.flatten()
len(set(nan_host) | set(nan_type))
fh = open('bioproject_descr_miss_biosam_non_akk.tsv', 'a')
asms = set(nan_type.tolist() + nan_host.tolist())
for idx,row in asm_biosam_bioproj.set_index('assembly_accession').loc[asms, :].iterrows():
    bp = row['GB_BioProjects']
    desc = ! esearch -db bioproject -query $bp | efetch -format docsum |  xtract -pattern DocumentSummary -element Project_Name,Project_Title,Project_Description,Project_Target_Scope
    desc_ls = desc.get_spstr().split('\t')
    desc_ls.insert(0, row['bioproject'])
    desc_ls.insert(0, row['biosample'])
    desc_ls.insert(0, idx)#assembly accession
    print('\t'.join(desc_ls), file=fh)
fh.close()

# %%
regex = ("'metagenome|metagenomic|microbiome|biome|gut|bucal|respiratory|mud|forest"
         "soil|sludge|water|marine|ocean|sediment|seawater|freshwater|freshwaters|feces|fecal|uncultured'")
ln_meta_non_akk_bp = build_line_source('bioproject_descr_miss_biosam_non_akk.tsv', regex, file_pattern=False)
print(repr(ln_meta_non_akk_bp))
acc_meta_non_akk_bp = build_acc_host(ln_meta_non_akk_bp, 'bioproject_descr_miss_biosam_non_akk.tsv')
print(set(acc_meta_non_akk_bp.values()), len(acc_meta_non_akk_bp))
# Out:
# rg -woni 'metagenome|metagenomic|microbiome|biome|gut|bucal|respiratory|mud|forestsoil|sludge|water|marine|ocean|sediment|seawater|freshwater|freshwaters|feces|fecal|uncultured' bioproject_descr_miss_biosam_non_akk.tsv | sort -h | uniq
# '55:marine\n93:marine\n131:marine\n'
# 1
# index for the list in python: 130
# {'marine'} 1

# %%
acc_meta_non_akk_bp
# Out:
# defaultdict(None, {'GCA_000155695.1': 'marine'})

# %%
regex = ("'isolate|isolated|isolates|monoisolate|culture|cultured|cultivation|cultivated'")
ln_culture_non_akk_bp = build_line_source('bioproject_descr_miss_biosam_non_akk.tsv', regex, file_pattern=False)
print(repr(ln_culture_non_akk_bp[:200]))
acc_culture_non_akk_bp = build_acc_host(ln_culture_non_akk_bp, 'bioproject_descr_miss_biosam_non_akk.tsv')
print(set(acc_culture_non_akk_bp.values()), len(acc_culture_non_akk_bp))
# Out:
# rg -woni 'isolate|isolated|isolates|monoisolate|culture|cultured|cultivation|cultivated' bioproject_descr_miss_biosam_non_akk.tsv | sort -h | uniq
# '48:cultivated\n48:isolates\n49:cultivated\n49:isolates\n54:isolated\n55:isolated\n70:isolated\n71:cultivated\n71:isolates\n79:Monoisolate\n86:cultivated\n86:isolates\n87:cultivated\n87:isolates\n92:isolated\n92:Mono'
# 35
# index for the list in python: 151
# {'monoisolate', 'isolates'} 35

# %%
set(acc_culture_non_akk_bp.keys()) & asms, len(set(acc_culture_non_akk_bp.keys()) & asms), len(acc_culture_non_akk_bp), len(asms)
# Out:
# ({'GCA_000155695.1',
#   'GCA_000242935.3',
#   'GCA_000243495.3',
#   'GCA_000526255.1',
#   'GCA_000739615.1',
#   'GCA_000739655.1',
#   'GCA_003054655.1',
#   'GCA_003054665.1',
#   'GCA_003054695.1',
#   'GCA_016811075.1',
#   'GCF_000019665.1',
#   'GCF_000019965.1',
#   'GCF_000172155.1',
#   'GCF_000172555.1',
#   'GCF_000173075.1',
#   'GCF_000297415.1',
#   'GCF_000379365.1',
#   'GCF_000817245.1',
#   'GCF_001613545.1',
#   'GCF_003054705.1',
#   'GCF_004341915.1',
#   'GCF_004364345.1',
#   'GCF_007475525.1',
#   'GCF_007992435.1',
#   'GCF_011044495.1',
#   'GCF_011044775.1',
#   'GCF_012913485.1',
#   'GCF_014201715.1',
#   'GCF_017310545.1',
#   'GCF_900104925.1',
#   'GCF_900105685.1',
#   'GCF_900141815.1',
#   'GCF_900167535.1',
#   'GCF_902143375.2',
#   'GCF_902143385.2'},
#  35,
#  35,
#  38)

# %% [markdown]
# **So all the assemblies in the dictionary are missing from the table, not need to create a new filtered dictionary**

# %%
merged_non_akk['type_of_sample'].value_counts(), merged_non_akk['type_of_sample'].isna().sum()
# Out:
# (metagenome    321
#  culture        50
#  Name: type_of_sample, dtype: int64,
#  13)

# %%
add_info_to_summary(merged_non_akk,'type_of_sample', acc_culture_non_akk_bp)
# Out:
# metagenome     321
# monoisolate     31
# culture         28
# isolates         4
# Name: type_of_sample, dtype: int64
# 0

# %%
common_to_sp  = {'isolate':'culture', 'isolated':'culture', 'isolates':'culture', 'monoisolate':'culture'}
merged_non_akk['type_of_sample'].replace(common_to_sp, inplace=True)
merged_non_akk['type_of_sample'].value_counts(), merged_non_akk['type_of_sample'].isna().sum()
# Out:
# (metagenome    321
#  culture        63
#  Name: type_of_sample, dtype: int64,
#  0)

# %%
merged_non_akk.to_csv(qc_path.joinpath('merged_non_akk.tsv'), sep='\t', index=False)
